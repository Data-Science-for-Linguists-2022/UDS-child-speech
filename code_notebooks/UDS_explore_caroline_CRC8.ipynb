# %% [markdown]
# # UDS and "try" constructions
#
# Caroline Gish | cng18@pitt.edu
#
# This Jupyter Notebook contains all of the work I did with the UDS dataset after I understood a bit of how to traverse it.
#
# nbviewer view here: https://nbviewer.org/github/Data-Science-for-Linguists-2022/UDS-child-speech/blob/main/notebooks/UDS_explore_caroline_CRC7.ipynb

# %% [markdown]
# ### Table of Contents
#
# - [1. Exploring UDS with CRC](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#1.-Exploring-UDS-with-CRC)
# - [2. Importing Corpus](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#2.--Importing-corpus)
# - [3. Finding "try" sentences](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#3.--Finding-%22try%22-sentences)
#     - [3-1. "try" sentences where relation is not xcomp](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#3-1.-%22try%22-sentences-where-relation-is-not-xcomp)
#     - [3-2. Back to sentence ewt-dev-539 for exploration](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#3-2.-Back-to-sentence-ewt-dev-539-for-exploration)
# - [4. Info on "try" verb sentences](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#3.--Finding-%22try%22-sentences)
#     - [4-1. Trying out helper functions](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#4-1.-Trying-out-helper-functions-(from-Na-Rae---thank-you!))
#     - [4-2. Types of relations](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#4-2.-Types-of-relations)
# - [5. Specific info for sentences with "try" constructions](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#5.-Specific-info-for-sentences-with-%22try%22-constructions)
#     - [5-1. Create DataFrame with sentence and word info](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#5-1.-Create-DataFrame-with-sentence-and-word-info)
# - [6. Closer look at node type subspaces (of interest)](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#6.-Closer-look-at-node-type-subspaces-(of-interest))
#     - [6-1. Factuality](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#6-1.-Factuality)
#     - [6-2. Event structure](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#6-2.-Event-structure)
#     - [6-3. Genericity](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#6-3.-Genericity)
#     - [6-4. Values for subspaces](https://ondemand.htc.crc.pitt.edu/node/htc-n30.crc.pitt.edu/40835/lab/tree/hw4_yelp/UDS_explore_caroline.ipynb#6-4.-Values-for-subspaces)

# %% [markdown]
# ## 1. Exploring UDS with CRC
#
# Installing on CRC done via two commands:
#
# - `module load python/ondemand-jupyter-python3.8`
#
# - `pip install --user git+https://github.com/decompositional-semantics-initiative/decomp.git`
#
# additional:
#
# - `pip install pathlib`
# - `pip install ruamel-yaml`
# - `pip install pyqtwebengine==5.13`
# - `pip install pyqt5==5.13`

# %%
# %pprint   

from pprint import pprint
# Out:
# Pretty printing has been turned OFF

# %%
import pandas as pd

# %% [markdown]
# ## 2.  Importing corpus

# %%
from decomp import UDSCorpus

# %%
uds = UDSCorpus()

# %% [markdown]
# ## 3.  Finding "try" sentences

# %%
# all sentences with the string " try"

for x in uds:
    sent_text = uds[x].sentence
    if ' try ' in sent_text:    # based on text substring - need spaces because otherwise was getting 'try' as part of bigger string
        print(x, sent_text)
# Out:
# ewt-train-668 Moreover there are now major covert attempts under way to try and bring back to Kabul leading Taliban commanders , who have been living quietly in Pakistan and have taken no part in the Taliban insurgency .
# ewt-train-701 In a highly significant move Afghan Pashtun tribes along the Pakistan border warned the Taliban in Quetta and Chaman that if they try and disrupt the elections , they would be resisted .
# ewt-train-1195 If part of the public supports it , others tolerate it , many are afraid of it and some try to explain it away by poverty or by a miserable childhood , organized crime will thrive and so will terrorism .
# ewt-train-1328 Nevertheless , most European countries still trade with Iran , try to appease it and refuse to read the clear signals .
# ewt-dev-82 [ Am at a conference and ca n't blog much right now but will try to catch up the next couple of days . ]
# ewt-dev-157 I -- which I try to do , as best as I possibly can .
# ewt-dev-211 ( Only recently have a few experienced State Department Arabists been allowed in to try to begin mopping up the mess . )
# ewt-dev-1287 You can try picking up the eggs and holding it up against a very bright light .
# ewt-dev-1333 where can I get morcillas in tampa bay , I will like the argentinian type , but I will to try anothers please ?
# ewt-dev-1736 I had so many strawberries right on the field ... strongly recomend ... do nt forget to try their great ice cream
# ewt-dev-1774 Give them a try !
# ewt-dev-1984 If possible I try the services on myself before I bring in my son .
# ewt-test-31 The President has also said he would like to see Israel wiped off the map which he could n't even begin to try without nuclear weapons .
# ewt-test-209 Look at a map and you try to figure out how , in fall of 1999 , you could possibly pull off such an operation without Pakistani facilities .
# ewt-test-312 I 'll try to get back to you pronto .
# ewt-test-459 I need a new lawnmower , so I 'll try to bump it up a little more .
# ewt-test-695 I 'll try and send one of Peter Cox ' as well but may have some problems due to file size .
# ewt-test-992 Action Network is also a good place to post details of events , or try to rally together a group if you want to take action in your area .
# ewt-test-1368 just pray for her ad=nd try to hlep your dog and do some physical therapy on the hind legs and take her to the vet and ig it costs a whole lot ask hlep from you friends and family adn since she s not eating feed her by hand
# ewt-test-1453 Along with the great burger try a brick of onion rings if you are with someone .
# ewt-test-1850 I just wanted to try your clinic because I was not totally happy with my current therapist I regularly see .
# ewt-test-1916 I was with verizon and I checked my service with tmobile and it was great so I thought I would try tmobile .
# ewt-test-1981 I used to take my cars there all the time , but management changes hands too frequently , the service has been slow , and they often try to " add on " extra services , which sometimes is not needed .
# ewt-test-2065 Branch out and try something other than the Pad Thai , the curries are fantastic .

# %% [markdown]
# **In a lot of these sentences "try" functions as a marker of the future - for an experience that has not yet happened.**

# %%
# all sentences with string " tried"

for x in uds:
    sent_text = uds[x].sentence
    if ' tried ' in sent_text:    # based on text substring
        print(x, sent_text)
# Out:
# ewt-train-917 Afshari , who was posted in Germany and was responsible for receiving Mujahedeen children during the gulf war , said that when the German government tried to absorb Mujahedeen children into their education system , the Mujahedeen refused .
# ewt-train-5584 When Sabeer Bhatia came up with the business plan for the mail service , he tried all kinds of names ending in ' mail ' and finally settled for hotmail as it included the letters " html " - the programming language used to write web pages .
# ewt-train-5633 Anyway , I tried to get a preorder but no places were selling it so I missed out on 2/3 weekend events .
# ewt-train-6438 The Pew researchers tried to transcend the economic argument .
# ewt-train-7233 Have you tried using clockwork recovery ?
# ewt-train-8476 I would n't know -- I do n't particularly like scary movies , and I have n't tried this with my pet .
# ewt-train-8587 I have done a fair amount of metal casting , but never tried to build my own furnace , but I think your version is just too small and does n't get hot enough .
# ewt-train-8851 I add that in because there have been some people who have tried to claim citizenship by sending for their birth certificate when they were never really born in Canada or to Canadian parents .
# ewt-train-8887 Spa We tried the spa on the Liberty and loved it .
# ewt-train-9215 i have tried EVERYTHING i can to get him to eat but he refuses .
# ewt-train-9226 i have tried feeding him 5 or 6 live pinkies and 4 or 5 frozen ( thawed ) pinkies .
# ewt-test-180 Of course Bush would have tried to stop 9/11 if he had known it was coming .
# ewt-test-213 Clinton tried , and tried hard .
# ewt-test-287 These guys tried the Ken Lay route .
# ewt-test-566 i tried to say i was n't that drunk but z was n't having any of that conversation .
# ewt-test-1458 I 've tried bland white rice but he wo nt eat anything .
# ewt-test-1773 We have tried many different computer people until now - we will stick with Qualitech Computers !!!
# ewt-test-1817 When I tried to return it they refused , so I had to leave without a refund and still hungry .
# ewt-test-2062 We tried 4 different style of donuts , they were all the same when it came to quality .

# %% [markdown]
# The first sentence here is interesting - this is what I am interested in with the "try" construction.
#
# > ewt-dev-539 I tried to do it on the HRonline web - site , but the procedure is too complicated .
#
# So to what extent did the action occur?
#
# Take a closer look at sentence ewt-dev-539, but first create variable containing all the sentences with the verb "try".

# %%
# based on lemma + POS -> only verbs

try_sents = []
for x in uds:
    sent_text = uds[x].sentence
    sent_lem = [(v['lemma'], v['upos']) for (n,v) in uds[x].syntax_nodes.items()]
    sent_lem_set = set(sent_lem)
    if ('try', 'VERB') in sent_lem_set:
        print(x, sent_text)
        try_sents.append(x)
# Out:
# ewt-train-133 Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
# ewt-train-637 The neighbours are still interfering , but there are signs that rather than undermining Afghanistan 's stability they may now be trying to strengthen it .
# ewt-train-668 Moreover there are now major covert attempts under way to try and bring back to Kabul leading Taliban commanders , who have been living quietly in Pakistan and have taken no part in the Taliban insurgency .
# ewt-train-688 However powerful hardliners in Tehran may be trying to undermine that strategy and a new issue is likely to deepen the rift with the moderates .
# ewt-train-701 In a highly significant move Afghan Pashtun tribes along the Pakistan border warned the Taliban in Quetta and Chaman that if they try and disrupt the elections , they would be resisted .
# ewt-train-796 He was trying to buddy with Archibald and impress him .
# ewt-train-881 I read of a case not long ago when some people were trying to get a polygamous judge taken off the bench for not obeying state law .
# ewt-train-917 Afshari , who was posted in Germany and was responsible for receiving Mujahedeen children during the gulf war , said that when the German government tried to absorb Mujahedeen children into their education system , the Mujahedeen refused .
# ewt-train-1195 If part of the public supports it , others tolerate it , many are afraid of it and some try to explain it away by poverty or by a miserable childhood , organized crime will thrive and so will terrorism .
# ewt-train-1267 Can a policeman open fire on someone trying to kill him ?
# ewt-train-1278 Do you shoot back at someone trying to kill you , standing deliberately behind a group of children ?
# ewt-train-1288 It is trying to play ice hockey by sending a ballerina ice - skater into the ring or to knock out a heavyweight boxer by a chess player .
# ewt-train-1318 It is not surprising that Iran is so active in trying to incite a Shiite uprising in Iraq .
# ewt-train-1325 It is clearly trying to develop nuclear weapons .
# ewt-train-1328 Nevertheless , most European countries still trade with Iran , try to appease it and refuse to read the clear signals .
# ewt-train-1330 It is pointless to try to understand the subtle differences between the Sunni terror of Al Qaeda and Hamas and the Shiite terror of Hezbollah , Sadr and other Iranian - inspired enterprises .
# ewt-train-1447 Zacarias Moussaoui , who had a crop dusting manual when he was arrested , stayed at Sufaat 's condominium in 2000 when he was trying to arrange for flight lessons in Malaysia .
# ewt-train-1665 Most of my contact with financial advisors in the past has consisted of them suggesting a mutual fund , telling me to invest in Home Depot , Sun , and Coke , or trying to pass off their banks ' biased research reports as something valuable .
# ewt-test-287 These guys tried the Ken Lay route .
# ewt-test-312 I 'll try to get back to you pronto .
# ewt-test-349 We are still trying to work the PSE swap transaction , now that the forex desk has been able to find a fix for CPI in the market .
# ewt-test-459 I need a new lawnmower , so I 'll try to bump it up a little more .
# ewt-test-566 i tried to say i was n't that drunk but z was n't having any of that conversation .
# ewt-test-695 I 'll try and send one of Peter Cox ' as well but may have some problems due to file size .
# ewt-test-746 We are still trying to figure out some of the cash traders .
# ewt-test-992 Action Network is also a good place to post details of events , or try to rally together a group if you want to take action in your area .
# ewt-test-1361 o and the cheaper the better ( we are trying to save money now , sooo .. that d b helpful ) thanks
# ewt-test-1365 Try SanFranGuide.com
# ewt-test-1368 just pray for her ad=nd try to hlep your dog and do some physical therapy on the hind legs and take her to the vet and ig it costs a whole lot ask hlep from you friends and family adn since she s not eating feed her by hand
# ewt-test-1386 try yelp.com
# ewt-test-1453 Along with the great burger try a brick of onion rings if you are with someone .
# ewt-test-1458 I 've tried bland white rice but he wo nt eat anything .
# ewt-test-1474 I have a friend out in Chicago this week , and I am trying to remember the name of an awesome hibachi style restaurant i visited while out there a couple years ago .
# ewt-test-1529 You are busy , you do n't have to sit face to face to try
# ewt-test-1773 We have tried many different computer people until now - we will stick with Qualitech Computers !!!
# ewt-test-1817 When I tried to return it they refused , so I had to leave without a refund and still hungry .
# ewt-test-1850 I just wanted to try your clinic because I was not totally happy with my current therapist I regularly see .
# ewt-test-1916 I was with verizon and I checked my service with tmobile and it was great so I thought I would try tmobile .
# ewt-test-1981 I used to take my cars there all the time , but management changes hands too frequently , the service has been slow , and they often try to " add on " extra services , which sometimes is not needed .
# ewt-test-2062 We tried 4 different style of donuts , they were all the same when it came to quality .
# ewt-test-2065 Branch out and try something other than the Pad Thai , the curries are fantastic .

# %%
len(try_sents)
# Out:
# 236

# %% [markdown]
# Now lots of "try" constructions once we base on lemma, and the kinds of sentences I want.

# %%
try_sents[100]
# Out:
# 'ewt-train-8851'

# %% [markdown]
# `try_sents` is list of sentence IDs

# %%
# some info about the sentences

for s in try_sents[:3]:      # first 3
    print()
    for (n, v) in uds[s].syntax_nodes.items():
        print(n, v['form'], v['lemma'], v['xpos'], v['upos'], sep="\t")
# Out:
# ewt-train-133-syntax-1	Musharraf	Musharraf	NNP	PROPN
# ewt-train-133-syntax-2	has	have	VBZ	AUX
# ewt-train-133-syntax-3	been	be	VBN	AUX
# ewt-train-133-syntax-4	trying	try	VBG	VERB
# ewt-train-133-syntax-5	to	to	TO	PART
# ewt-train-133-syntax-6	purge	purge	VB	VERB
# ewt-train-133-syntax-7	his	he	PRP$	PRON
# ewt-train-133-syntax-8	officer	officer	NN	NOUN
# ewt-train-133-syntax-9	corps	corps	NN	NOUN
# ewt-train-133-syntax-10	of	of	IN	ADP
# ewt-train-133-syntax-11	the	the	DT	DET
# ewt-train-133-syntax-12	substantial	substantial	JJ	ADJ
# ewt-train-133-syntax-13	number	number	NN	NOUN
# ewt-train-133-syntax-14	of	of	IN	ADP
# ewt-train-133-syntax-15	al	al	NNP	PROPN
# ewt-train-133-syntax-16	-	-	HYPH	PUNCT
# ewt-train-133-syntax-17	Qaeda	Qaeda	NNP	PROPN
# ewt-train-133-syntax-18	sympathizers	sympathizer	NNS	NOUN
# ewt-train-133-syntax-19	.	.	.	PUNCT
#
# ewt-train-637-syntax-1	The	the	DT	DET
# ewt-train-637-syntax-2	neighbours	neighbour	NNS	NOUN
# ewt-train-637-syntax-3	are	be	VBP	AUX
# ewt-train-637-syntax-4	still	still	RB	ADV
# ewt-train-637-syntax-5	interfering	interfere	VBG	VERB
# ewt-train-637-syntax-6	,	,	,	PUNCT
# ewt-train-637-syntax-7	but	but	CC	CONJ
# ewt-train-637-syntax-8	there	there	EX	PRON
# ewt-train-637-syntax-9	are	be	VBP	VERB
# ewt-train-637-syntax-10	signs	sign	NNS	NOUN
# ewt-train-637-syntax-11	that	that	IN	SCONJ
# ewt-train-637-syntax-12	rather	rather	IN	ADP
# ewt-train-637-syntax-13	than	than	IN	SCONJ
# ewt-train-637-syntax-14	undermining	undermine	VBG	VERB
# ewt-train-637-syntax-15	Afghanistan	Afghanistan	NNP	PROPN
# ewt-train-637-syntax-16	's	's	POS	PART
# ewt-train-637-syntax-17	stability	stability	NN	NOUN
# ewt-train-637-syntax-18	they	they	PRP	PRON
# ewt-train-637-syntax-19	may	may	MD	AUX
# ewt-train-637-syntax-20	now	now	RB	ADV
# ewt-train-637-syntax-21	be	be	VB	AUX
# ewt-train-637-syntax-22	trying	try	VBG	VERB
# ewt-train-637-syntax-23	to	to	TO	PART
# ewt-train-637-syntax-24	strengthen	strengthen	VB	VERB
# ewt-train-637-syntax-25	it	it	PRP	PRON
# ewt-train-637-syntax-26	.	.	.	PUNCT
#
# ewt-train-668-syntax-1	Moreover	moreover	RB	ADV
# ewt-train-668-syntax-2	there	there	EX	PRON
# ewt-train-668-syntax-3	are	be	VBP	VERB
# ewt-train-668-syntax-4	now	now	RB	ADV
# ewt-train-668-syntax-5	major	major	JJ	ADJ
# ewt-train-668-syntax-6	covert	covert	JJ	ADJ
# ewt-train-668-syntax-7	attempts	attempt	NNS	NOUN
# ewt-train-668-syntax-8	under	under	IN	ADP
# ewt-train-668-syntax-9	way	way	NN	NOUN
# ewt-train-668-syntax-10	to	to	TO	PART
# ewt-train-668-syntax-11	try	try	VB	VERB
# ewt-train-668-syntax-12	and	and	CC	CONJ
# ewt-train-668-syntax-13	bring	bring	VB	VERB
# ewt-train-668-syntax-14	back	back	RB	ADV
# ewt-train-668-syntax-15	to	to	IN	ADP
# ewt-train-668-syntax-16	Kabul	Kabul	NNP	PROPN
# ewt-train-668-syntax-17	leading	lead	VBG	VERB
# ewt-train-668-syntax-18	Taliban	Taliban	NNP	PROPN
# ewt-train-668-syntax-19	commanders	commander	NNS	NOUN
# ewt-train-668-syntax-20	,	,	,	PUNCT
# ewt-train-668-syntax-21	who	who	WP	PRON
# ewt-train-668-syntax-22	have	have	VBP	AUX
# ewt-train-668-syntax-23	been	be	VBN	AUX
# ewt-train-668-syntax-24	living	live	VBG	VERB
# ewt-train-668-syntax-25	quietly	quietly	RB	ADV
# ewt-train-668-syntax-26	in	in	IN	ADP
# ewt-train-668-syntax-27	Pakistan	Pakistan	NNP	PROPN
# ewt-train-668-syntax-28	and	and	CC	CONJ
# ewt-train-668-syntax-29	have	have	VBP	AUX
# ewt-train-668-syntax-30	taken	take	VBN	VERB
# ewt-train-668-syntax-31	no	no	DT	DET
# ewt-train-668-syntax-32	part	part	NN	NOUN
# ewt-train-668-syntax-33	in	in	IN	ADP
# ewt-train-668-syntax-34	the	the	DT	DET
# ewt-train-668-syntax-35	Taliban	Taliban	NNP	PROPN
# ewt-train-668-syntax-36	insurgency	insurgency	NN	NOUN
# ewt-train-668-syntax-37	.	.	.	PUNCT

# %% [markdown]
# https://universaldependencies.org/format.html
#
# - FORM: Word form or punctuation symbol.
# - LEMMA: Lemma or stem of word form.
# - UPOS: Universal part-of-speech tag.
# - XPOS: Language-specific part-of-speech tag; underscore if not available.
# - DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one.

# %%
# another grouping of try sentences
# this time (sentence, node id)

try_sents_id = []
for x in uds:
    sent_text = uds[x].sentence
    # key: ('try', 'VERB'), value: syntax node id
    sent_lem_dict = {(v['lemma'], v['upos']):n for (n,v) in uds[x].syntax_nodes.items()}
    for (n,v) in uds[x].syntax_nodes.items():
        if v['lemma']=='try' and v['upos']=='VERB':
            try_sents_id.append( (x,n) )    # (sentence, node id for 'try')

# %%
try_sents_id[0]
# Out:
# ('ewt-train-133', 'ewt-train-133-syntax-4')

# %% [markdown]
# `try_sents_id` is list of (sentence ID, node ID) tuples

# %%
def print_udep(udstree_id):
    "Custom printing function: also prints dependency info"
    print(udstree_id)
    print(uds[udstree_id].sentence)
    edge_dict = {e2:(e1,v['deprel']) for ((e1,e2),v) in uds[udstree_id].syntax_edges().items()}
    for (n,v) in uds[udstree_id].syntax_nodes.items():
        print(n, v['form'], v['lemma'], v['xpos'], v['upos'], sep="\t", end='\t')
        if n in edge_dict:
            print(':'.join(edge_dict[n]))
        else: print('ERROR')

# %%
for s, trid in try_sents_id[:3]:
    print()
    print('try verb is found at:', trid)
    print('-----------')
    print_udep(s)
# Out:
# try verb is found at: ewt-train-133-syntax-4
# -----------
# ewt-train-133
# Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
# ewt-train-133-syntax-1	Musharraf	Musharraf	NNP	PROPN	ewt-train-133-syntax-4:nsubj
# ewt-train-133-syntax-2	has	have	VBZ	AUX	ewt-train-133-syntax-4:aux
# ewt-train-133-syntax-3	been	be	VBN	AUX	ewt-train-133-syntax-4:aux
# ewt-train-133-syntax-4	trying	try	VBG	VERB	ewt-train-133-root-0:root
# ewt-train-133-syntax-5	to	to	TO	PART	ewt-train-133-syntax-6:mark
# ewt-train-133-syntax-6	purge	purge	VB	VERB	ewt-train-133-syntax-4:xcomp
# ewt-train-133-syntax-7	his	he	PRP$	PRON	ewt-train-133-syntax-9:nmod:poss
# ewt-train-133-syntax-8	officer	officer	NN	NOUN	ewt-train-133-syntax-9:compound
# ewt-train-133-syntax-9	corps	corps	NN	NOUN	ewt-train-133-syntax-6:dobj
# ewt-train-133-syntax-10	of	of	IN	ADP	ewt-train-133-syntax-13:case
# ewt-train-133-syntax-11	the	the	DT	DET	ewt-train-133-syntax-13:det
# ewt-train-133-syntax-12	substantial	substantial	JJ	ADJ	ewt-train-133-syntax-13:amod
# ewt-train-133-syntax-13	number	number	NN	NOUN	ewt-train-133-syntax-6:nmod
# ewt-train-133-syntax-14	of	of	IN	ADP	ewt-train-133-syntax-18:case
# ewt-train-133-syntax-15	al	al	NNP	PROPN	ewt-train-133-syntax-17:compound
# ewt-train-133-syntax-16	-	-	HYPH	PUNCT	ewt-train-133-syntax-17:punct
# ewt-train-133-syntax-17	Qaeda	Qaeda	NNP	PROPN	ewt-train-133-syntax-18:compound
# ewt-train-133-syntax-18	sympathizers	sympathizer	NNS	NOUN	ewt-train-133-syntax-13:nmod
# ewt-train-133-syntax-19	.	.	.	PUNCT	ewt-train-133-syntax-4:punct
#
# try verb is found at: ewt-train-637-syntax-22
# -----------
# ewt-train-637
# The neighbours are still interfering , but there are signs that rather than undermining Afghanistan 's stability they may now be trying to strengthen it .
# ewt-train-637-syntax-1	The	the	DT	DET	ewt-train-637-syntax-2:det
# ewt-train-637-syntax-2	neighbours	neighbour	NNS	NOUN	ewt-train-637-syntax-5:nsubj
# ewt-train-637-syntax-3	are	be	VBP	AUX	ewt-train-637-syntax-5:aux
# ewt-train-637-syntax-4	still	still	RB	ADV	ewt-train-637-syntax-5:advmod
# ewt-train-637-syntax-5	interfering	interfere	VBG	VERB	ewt-train-637-root-0:root
# ewt-train-637-syntax-6	,	,	,	PUNCT	ewt-train-637-syntax-5:punct
# ewt-train-637-syntax-7	but	but	CC	CONJ	ewt-train-637-syntax-5:cc
# ewt-train-637-syntax-8	there	there	EX	PRON	ewt-train-637-syntax-9:expl
# ewt-train-637-syntax-9	are	be	VBP	VERB	ewt-train-637-syntax-5:conj
# ewt-train-637-syntax-10	signs	sign	NNS	NOUN	ewt-train-637-syntax-9:nsubj
# ewt-train-637-syntax-11	that	that	IN	SCONJ	ewt-train-637-syntax-22:mark
# ewt-train-637-syntax-12	rather	rather	IN	ADP	ewt-train-637-syntax-14:mark
# ewt-train-637-syntax-13	than	than	IN	SCONJ	ewt-train-637-syntax-12:mwe
# ewt-train-637-syntax-14	undermining	undermine	VBG	VERB	ewt-train-637-syntax-22:advcl
# ewt-train-637-syntax-15	Afghanistan	Afghanistan	NNP	PROPN	ewt-train-637-syntax-17:nmod:poss
# ewt-train-637-syntax-16	's	's	POS	PART	ewt-train-637-syntax-15:case
# ewt-train-637-syntax-17	stability	stability	NN	NOUN	ewt-train-637-syntax-14:dobj
# ewt-train-637-syntax-18	they	they	PRP	PRON	ewt-train-637-syntax-22:nsubj
# ewt-train-637-syntax-19	may	may	MD	AUX	ewt-train-637-syntax-22:aux
# ewt-train-668-syntax-25	quietly	quietly	RB	ADV	ewt-train-668-syntax-24:advmod
# ewt-train-668-syntax-26	in	in	IN	ADP	ewt-train-668-syntax-27:case
# ewt-train-668-syntax-27	Pakistan	Pakistan	NNP	PROPN	ewt-train-668-syntax-24:nmod
# ewt-train-668-syntax-28	and	and	CC	CONJ	ewt-train-668-syntax-24:cc
# ewt-train-668-syntax-29	have	have	VBP	AUX	ewt-train-668-syntax-30:aux
# ewt-train-668-syntax-30	taken	take	VBN	VERB	ewt-train-668-syntax-24:conj
# ewt-train-668-syntax-31	no	no	DT	DET	ewt-train-668-syntax-32:neg
# ewt-train-668-syntax-32	part	part	NN	NOUN	ewt-train-668-syntax-30:dobj
# ewt-train-668-syntax-33	in	in	IN	ADP	ewt-train-668-syntax-36:case
# ewt-train-668-syntax-34	the	the	DT	DET	ewt-train-668-syntax-36:det
# ewt-train-668-syntax-35	Taliban	Taliban	NNP	PROPN	ewt-train-668-syntax-36:compound
# ewt-train-668-syntax-36	insurgency	insurgency	NN	NOUN	ewt-train-668-syntax-30:nmod
# ewt-train-668-syntax-37	.	.	.	PUNCT	ewt-train-668-syntax-3:punct

# %%
try_sents[0]   # first one
# Out:
# 'ewt-train-133'

# %%
for (n1, n2) in uds['ewt-train-133'].syntax_edges():
    if n1 == 'ewt-train-133-syntax-4':
        print(uds['ewt-train-133'].syntax_edges()[(n1,n2)])
        
# want xcomp deprel label, which is 'ewt-train-133-syntax-6'
# Out:
# {'deprel': 'nsubj', 'domain': 'syntax', 'type': 'dependency', 'id': 'ewt-train-133-syntax-1'}
# {'deprel': 'aux', 'domain': 'syntax', 'type': 'dependency', 'id': 'ewt-train-133-syntax-2'}
# {'deprel': 'aux', 'domain': 'syntax', 'type': 'dependency', 'id': 'ewt-train-133-syntax-3'}
# {'deprel': 'xcomp', 'domain': 'syntax', 'type': 'dependency', 'id': 'ewt-train-133-syntax-6'}
# {'deprel': 'punct', 'domain': 'syntax', 'type': 'dependency', 'id': 'ewt-train-133-syntax-19'}

# %% [markdown]
# ### 3-1. "try" sentences where relation is not xcomp
#
# - "try and VERB' construction
#     - "try and xxx" construction
#     - 'bring' is dependent on 'try' as conj
#
# - "Try NOUN" construction
#     - 'obj' dependency label.

# %%
pprint(uds['ewt-train-133'].syntax_edges())
# Out:
# {('ewt-train-133-root-0', 'ewt-train-133-syntax-4'): {'deprel': 'root',
#                                                       'domain': 'syntax',
#                                                       'id': 'ewt-train-133-syntax-4',
#                                                       'type': 'dependency'},
#  ('ewt-train-133-syntax-13', 'ewt-train-133-syntax-10'): {'deprel': 'case',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-10',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-13', 'ewt-train-133-syntax-11'): {'deprel': 'det',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-11',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-13', 'ewt-train-133-syntax-12'): {'deprel': 'amod',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-12',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-13', 'ewt-train-133-syntax-18'): {'deprel': 'nmod',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-18',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-17', 'ewt-train-133-syntax-15'): {'deprel': 'compound',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-15',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-17', 'ewt-train-133-syntax-16'): {'deprel': 'punct',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-16',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-18', 'ewt-train-133-syntax-14'): {'deprel': 'case',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-14',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-18', 'ewt-train-133-syntax-17'): {'deprel': 'compound',
#                                                           'domain': 'syntax',
#                                                           'id': 'ewt-train-133-syntax-17',
#                                                           'type': 'dependency'},
#  ('ewt-train-133-syntax-4', 'ewt-train-133-syntax-1'): {'deprel': 'nsubj',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-1',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-4', 'ewt-train-133-syntax-19'): {'deprel': 'punct',
#                                                          'domain': 'syntax',
#                                                          'id': 'ewt-train-133-syntax-19',
#                                                          'type': 'dependency'},
#  ('ewt-train-133-syntax-4', 'ewt-train-133-syntax-2'): {'deprel': 'aux',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-2',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-4', 'ewt-train-133-syntax-3'): {'deprel': 'aux',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-3',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-4', 'ewt-train-133-syntax-6'): {'deprel': 'xcomp',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-6',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-6', 'ewt-train-133-syntax-13'): {'deprel': 'nmod',
#                                                          'domain': 'syntax',
#                                                          'id': 'ewt-train-133-syntax-13',
#                                                          'type': 'dependency'},
#  ('ewt-train-133-syntax-6', 'ewt-train-133-syntax-5'): {'deprel': 'mark',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-5',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-6', 'ewt-train-133-syntax-9'): {'deprel': 'dobj',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-9',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-9', 'ewt-train-133-syntax-7'): {'deprel': 'nmod:poss',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-7',
#                                                         'type': 'dependency'},
#  ('ewt-train-133-syntax-9', 'ewt-train-133-syntax-8'): {'deprel': 'compound',
#                                                         'domain': 'syntax',
#                                                         'id': 'ewt-train-133-syntax-8',
#                                                         'type': 'dependency'}}

# %%
for ((n1,n2),v) in uds['ewt-train-133'].syntax_edges().items():
    if n1=='ewt-train-133-syntax-4' and v['deprel']=='xcomp': 
        print (n2)
# Out:
# ewt-train-133-syntax-6

# %% [markdown]
# ### 3-2. Back to sentence ewt-dev-539 for exploration

# %%
# sentence text

print(uds["ewt-dev-539"].name, '   ', uds['ewt-dev-539'].sentence)
# Out:
# ewt-dev-539     I tried to do it on the HRonline web - site , but the procedure is too complicated .

# %% [markdown]
# The "doing" is being tried.

# %% [markdown]
# Look at dependencies in the sentence:
#
# from https://raw.githubusercontent.com/UniversalDependencies/UD_English-EWT/master/en_ewt-ud-dev.conllu
#
# sent_id = email-enronsent30_02-0029
#
# - "try" is root (0)
# - "to" is dependent on "do"
# - "do" is dependent on "try"

# %%
# semantic nodes of ewt-dev-539

for x in uds["ewt-dev-539"].semantics_nodes.keys():
    print(x)
    if uds["ewt-dev-539"].semantics_nodes[x]['frompredpatt']: 
        print(uds["ewt-dev-539"].head(x, ['form', 'lemma']))
# Out:
# ewt-dev-539-semantics-pred-2
# (2, ['tried', 'try'])
# ewt-dev-539-semantics-pred-4
# (4, ['do', 'do'])
# ewt-dev-539-semantics-pred-18
# (18, ['complicated', 'complicated'])
# ewt-dev-539-semantics-arg-1
# (1, ['I', 'I'])
# ewt-dev-539-semantics-arg-4
# (4, ['do', 'do'])
# ewt-dev-539-semantics-arg-5
# (5, ['it', 'it'])
# ewt-dev-539-semantics-arg-11
# (11, ['site', 'site'])
# ewt-dev-539-semantics-arg-15
# (15, ['procedure', 'procedure'])
# ewt-dev-539-semantics-pred-root
# ewt-dev-539-semantics-arg-0
# ewt-dev-539-semantics-arg-author
# ewt-dev-539-semantics-arg-addressee

# %% [markdown]
# Semantic nodes will return both argument and predicate nodes together

# %%
# just predicate nodes of ewt-dev-539

for pred in uds["ewt-dev-539"].predicate_nodes.keys():
    print(pred)
    if uds["ewt-dev-539"].predicate_nodes[pred]['frompredpatt']: # this value is TRUE for non-performative nodes
        print(uds["ewt-dev-539"].head(pred, ['form', 'lemma']))
# Out:
# ewt-dev-539-semantics-pred-2
# (2, ['tried', 'try'])
# ewt-dev-539-semantics-pred-4
# (4, ['do', 'do'])
# ewt-dev-539-semantics-pred-18
# (18, ['complicated', 'complicated'])
# ewt-dev-539-semantics-pred-root

# %%
# A single entry, for "try"

pprint(uds["ewt-dev-539"].predicate_nodes['ewt-dev-539-semantics-pred-2'])
# Out:
# {'domain': 'semantics',
#  'event_structure': {'avg_part_duration_lbound-centuries': {'confidence': 1,
#                                                             'value': -0.4185},
#                      'avg_part_duration_lbound-days': {'confidence': 1,
#                                                        'value': -1.3143},
#                      'avg_part_duration_lbound-decades': {'confidence': 1,
#                                                           'value': -0.4689},
#                      'avg_part_duration_lbound-forever': {'confidence': 1,
#                                                           'value': -1.6181},
#                      'avg_part_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                         'value': -1.2363},
#                      'avg_part_duration_lbound-hours': {'confidence': 1,
#                                                         'value': -1.47},
#                      'avg_part_duration_lbound-instant': {'confidence': 1,
#                                                           'value': -2.9899},
#                      'avg_part_duration_lbound-minutes': {'confidence': 1,
#                                                           'value': 1.1131},
#                      'avg_part_duration_lbound-months': {'confidence': 1,
#                                                          'value': -1.1087},
#                      'avg_part_duration_lbound-seconds': {'confidence': 1,
#                                                           'value': 1.4324},
#                      'avg_part_duration_lbound-weeks': {'confidence': 1,
#                                                         'value': -0.9089},
#                      'avg_part_duration_lbound-years': {'confidence': 1,
#                                                         'value': -1.4308},
#                      'avg_part_duration_ubound-centuries': {'confidence': 0,
#                                                             'value': -0.3876},
#                      'avg_part_duration_ubound-days': {'confidence': 0,
#                                                        'value': -1.2632},
#                      'avg_part_duration_ubound-decades': {'confidence': 0,
#                                                           'value': -0.4426},
#                      'avg_part_duration_ubound-forever': {'confidence': 0,
#                                                           'value': -1.5643},
#                      'avg_part_duration_ubound-fractions_of_a_second': {'confidence': 0,
#                                                                         'value': -1.1848},
#                      'avg_part_duration_ubound-hours': {'confidence': 0,
#                                                         'value': 1.3385},
#                      'avg_part_duration_ubound-instant': {'confidence': 0,
#                                                           'value': -2.9487},
#                      'avg_part_duration_ubound-minutes': {'confidence': 0,
#                                                           'value': 1.1902},
#                      'avg_part_duration_ubound-months': {'confidence': 0,
#                                                          'value': -1.066},
#                      'avg_part_duration_ubound-seconds': {'confidence': 0,
#                                                           'value': -1.3272},
#                      'avg_part_duration_ubound-weeks': {'confidence': 0,
#                                                         'value': -0.854},
#                      'avg_part_duration_ubound-years': {'confidence': 0,
#                                                         'value': -1.4154},
#                      'dynamic': {'confidence': 0.999998152256012,
#                                  'value': 1.2362141609191895},
#                      'natural_parts': {'confidence': 0.5080714225769043,
#                                        'value': 0.1734340786933899},
#                      'part_similarity': {'confidence': 0.49542611837387085,
#                                          'value': 0.1193103939294815},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -0.3917},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.3579},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -0.5761},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -2.3397},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.3633},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.2776},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -1.7015},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': 1.2389},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -0.9623},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': -1.1143},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -0.94},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.2534},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -0.3917},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.3579},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -0.5761},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -2.3397},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.3633},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.2776},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -1.7015},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': 1.2389},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -0.9623},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.1143},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -0.94},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.2534},
#                      'telic': {'confidence': 0.9999978542327881,
#                                'value': 1.266179084777832}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.0489}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 0.6365, 'value': 0.0092},
#                 'pred-hypothetical': {'confidence': 0.6522, 'value': -0.0875},
#                 'pred-particular': {'confidence': 0.5039, 'value': -0.0161}},
#  'time': {'dur-centuries': {'confidence': 0.9236, 'value': -1.4201},
#           'dur-days': {'confidence': 0.9236, 'value': 0.3023},
#           'dur-decades': {'confidence': 0.9236, 'value': -1.3925},
#           'dur-forever': {'confidence': 0.9236, 'value': -1.5114},
#           'dur-hours': {'confidence': 0.9236, 'value': -1.2337},
#           'dur-instant': {'confidence': 0.9236, 'value': -1.5655},
#           'dur-minutes': {'confidence': 0.9236, 'value': 1.213},
#           'dur-months': {'confidence': 0.9236, 'value': -1.5097},
#           'dur-seconds': {'confidence': 0.9236, 'value': -1.2546},
#           'dur-weeks': {'confidence': 0.9236, 'value': 0.3487},
#           'dur-years': {'confidence': 0.9236, 'value': -1.3196}},
#  'type': 'predicate'}

# %%
# A single entry, for "do"

pprint(uds["ewt-dev-539"].predicate_nodes['ewt-dev-539-semantics-pred-4'])
# Out:
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.5674227476119995,
#                                  'value': 0.07712224125862122},
#                      'natural_parts': {'confidence': 0.9999988675117493,
#                                        'value': -1.0767347812652588},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -0.685},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.4659},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -1.0697},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': 1.6609},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.0107},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.9219},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -0.1895},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.9988},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -1.0494},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': 0.1533},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -0.8787},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.5155},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -0.685},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.4659},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -1.0697},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': 1.6609},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.0107},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.9219},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -0.1895},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.9988},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -1.0494},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': 0.1533},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -0.8787},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.5155},
#                      'telic': {'confidence': 0.9999988675117493,
#                                'value': -1.076088786125183}},
#  'factuality': {'factual': {'confidence': 0.968, 'value': -0.336}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 1.1015},
#                 'pred-hypothetical': {'confidence': 0.6153, 'value': -0.1813},
#                 'pred-particular': {'confidence': 1.0, 'value': 1.1015}},
#  'time': {'dur-centuries': {'confidence': 0.4814, 'value': -1.3204},
#           'dur-days': {'confidence': 0.4814, 'value': 0.673},
#           'dur-decades': {'confidence': 0.4814, 'value': -1.5445},
#           'dur-forever': {'confidence': 0.4814, 'value': -1.4368},
#           'dur-hours': {'confidence': 0.4814, 'value': 0.7887},
#           'dur-instant': {'confidence': 0.4814, 'value': -1.5695},
#           'dur-minutes': {'confidence': 0.4814, 'value': 1.1613},
#           'dur-months': {'confidence': 0.4814, 'value': -1.4104},
#           'dur-seconds': {'confidence': 0.4814, 'value': -1.1141},
#           'dur-weeks': {'confidence': 0.4814, 'value': 0.4335},
#           'dur-years': {'confidence': 0.4814, 'value': -1.2676}},
#  'type': 'predicate'}

# %%
# relation between predicate "try" and argument "I":

pprint(uds["ewt-dev-539"].semantics_edges()[('ewt-dev-539-semantics-pred-2', 'ewt-dev-539-semantics-arg-1')])
# Out:
# {'domain': 'semantics',
#  'frompredpatt': True,
#  'id': 'ewt-dev-539-semantics-arg-1',
#  'protoroles': {'awareness': {'confidence': 1.0, 'value': 1.3575},
#                 'change_of_location': {'confidence': 0.2325, 'value': -0.1191},
#                 'change_of_possession': {'confidence': 1.0, 'value': -0.0},
#                 'change_of_state': {'confidence': 0.4282, 'value': 0.0066},
#                 'change_of_state_continuous': {'confidence': 0.4835,
#                                                'value': -0.0769},
#                 'existed_after': {'confidence': 1.0, 'value': 1.3577},
#                 'existed_before': {'confidence': 1.0, 'value': 1.3586},
#                 'existed_during': {'confidence': 1.0, 'value': 1.3578},
#                 'instigation': {'confidence': 1.0, 'value': 1.3572},
#                 'partitive': {'confidence': 1.0, 'value': -0.0},
#                 'sentient': {'confidence': 1.0, 'value': 1.3565},
#                 'volition': {'confidence': 1.0, 'value': 1.3558},
#                 'was_for_benefit': {'confidence': 1.0, 'value': 1.3565},
#                 'was_used': {'confidence': 0.3362, 'value': -0.002}},
#  'type': 'dependency'}

# %% [markdown]
# ## 4. Info on "try" verb sentences

# %%
# predicate nodes

for pred in uds["ewt-dev-539"].predicate_nodes:
    pprint(pred)
# Out:
# 'ewt-dev-539-semantics-pred-2'
# 'ewt-dev-539-semantics-pred-4'
# 'ewt-dev-539-semantics-pred-18'
# 'ewt-dev-539-semantics-pred-root'

# %%
# only 2 sentences now for exploration

for s in try_sents[:2]:     
    print('========================================================================', '\n')
    print('SENTENCE:', '\n', uds[s].name, '   ', uds[s].sentence, '\n')
    print('PREDICATES:')
    for pred in uds[s].predicate_nodes.keys():
        print(pred)
        if uds[s].predicate_nodes[pred]['frompredpatt']:
            print(uds[s].head(pred, ['form', 'lemma']))
    print('\n')
    for pred in uds[s].predicate_nodes:
        print('PREDICATE:', ' ', pred, '\n')
        pprint(uds[s].predicate_nodes[pred])
        print()
# Out:
# ========================================================================
#
# SENTENCE:
#  ewt-train-133     Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
#
# PREDICATES:
# ewt-train-133-semantics-pred-4
# (4, ['trying', 'try'])
# ewt-train-133-semantics-pred-6
# (6, ['purge', 'purge'])
# ewt-train-133-semantics-pred-root
#
#
# PREDICATE:   ewt-train-133-semantics-pred-4
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.9999978542327881,
#                                  'value': 1.2817959785461426},
#                      'natural_parts': {'confidence': 0.9999987483024597,
#                                        'value': -1.089069128036499},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -0.3542},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.1031},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -0.5771},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -0.3432},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.2291},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.7485},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -0.4193},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.8371},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -1.2285},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': 1.2515},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -0.6608},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.756},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -0.3678},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.0474},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -0.5431},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -0.3593},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.1701},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': 1.2838},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -0.4454},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.7417},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -1.1699},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.5175},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -0.62},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.6638},
#                      'telic': {'confidence': 0.9999978542327881,
#                                'value': 1.2817955017089844}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.2194}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 1.8713},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': -0.7177},
#                 'pred-particular': {'confidence': 1.0, 'value': 1.8712}},
#  'time': {'dur-centuries': {'confidence': 1.0, 'value': -0.8337},
#           'dur-days': {'confidence': 1.0, 'value': -1.2002},
#           'dur-decades': {'confidence': 1.0, 'value': -1.1133},
#           'dur-forever': {'confidence': 1.0, 'value': -0.3098},
#           'dur-hours': {'confidence': 1.0, 'value': -1.1744},
#           'dur-instant': {'confidence': 1.0, 'value': -0.4054},
#           'dur-minutes': {'confidence': 1.0, 'value': -1.0265},
#           'dur-months': {'confidence': 1.0, 'value': 1.0446},
#           'dur-seconds': {'confidence': 1.0, 'value': -0.9131},
#           'dur-weeks': {'confidence': 1.0, 'value': -1.3455},
#           'dur-years': {'confidence': 1.0, 'value': -1.0219}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-133-semantics-pred-6
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.9999985694885254,
#                                  'value': -1.1353638172149658},
#                      'natural_parts': {'confidence': 0.9999986290931702,
#                                        'value': -1.1353570222854614},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -0.515},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.3255},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -0.6394},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -2.2538},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.4623},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.2405},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': 1.3383},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.5571},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -0.9688},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': -1.0649},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -0.9533},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.2108},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -0.515},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.3255},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -0.6394},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -2.2538},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.4623},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.2405},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': 1.3383},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.5571},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -0.9688},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.0649},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -0.9533},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.2108},
#                      'telic': {'confidence': 0.9999986886978149,
#                                'value': -1.1354095935821533}},
#  'factuality': {'factual': {'confidence': 0.8706, 'value': 0.2707}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 0.4279},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': 0.4279},
#                 'pred-particular': {'confidence': 1.0, 'value': 0.4279}},
#  'time': {'dur-centuries': {'confidence': 0.5836, 'value': -0.98},
#           'dur-days': {'confidence': 0.5836, 'value': -1.2104},
#           'dur-decades': {'confidence': 0.5836, 'value': -1.0465},
#           'dur-forever': {'confidence': 0.5836, 'value': -0.4961},
#           'dur-hours': {'confidence': 0.5836, 'value': -1.1908},
#           'dur-instant': {'confidence': 0.5836, 'value': -0.5634},
#           'dur-minutes': {'confidence': 0.5836, 'value': -1.0486},
#           'dur-months': {'confidence': 0.5836, 'value': 0.8781},
#           'dur-seconds': {'confidence': 0.5836, 'value': -0.9104},
#           'dur-weeks': {'confidence': 0.5836, 'value': 0.6508},
#           'dur-years': {'confidence': 0.5836, 'value': -1.0337}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-133-semantics-pred-root
#
# {'domain': 'semantics', 'frompredpatt': False, 'type': 'predicate'}
#
# ========================================================================
#
# SENTENCE:
#  ewt-train-637     The neighbours are still interfering , but there are signs that rather than undermining Afghanistan 's stability they may now be trying to strengthen it .
#
# PREDICATES:
# ewt-train-637-semantics-pred-5
# (5, ['interfering', 'interfere'])
# ewt-train-637-semantics-pred-9
# (9, ['are', 'be'])
# ewt-train-637-semantics-pred-14
# (14, ['undermining', 'undermine'])
# ewt-train-637-semantics-pred-22
# (22, ['trying', 'try'])
# ewt-train-637-semantics-pred-24
# (24, ['strengthen', 'strengthen'])
# ewt-train-637-semantics-pred-root
#
#
# PREDICATE:   ewt-train-637-semantics-pred-5
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.9999987483024597,
#                                  'value': -1.0745394229888916},
#                      'natural_parts': {'confidence': 0.9999988079071045,
#                                        'value': -1.0745078325271606},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -0.4917},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.1586},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -0.9163},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -0.458},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.5215},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.9761},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': 1.7272},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -2.092},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -0.618},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': -2.5002},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -0.9733},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.4299},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -0.4917},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.1586},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -0.9163},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -0.458},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.5215},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.9761},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': 1.7272},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -2.092},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -0.618},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -2.5002},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -0.9733},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.4299},
#                      'telic': {'confidence': 0.9999987483024597,
#                                'value': -1.0744456052780151}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.0498}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 0.9482},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': -1.3616},
#                 'pred-particular': {'confidence': 1.0, 'value': 0.9482}},
#  'time': {'dur-centuries': {'confidence': 0.3961, 'value': -0.9553},
#           'dur-days': {'confidence': 0.3961, 'value': 1.0418},
#           'dur-decades': {'confidence': 0.3961, 'value': 0.8798},
#           'dur-forever': {'confidence': 0.3961, 'value': -1.1847},
#           'dur-hours': {'confidence': 0.3961, 'value': -0.9873},
#           'dur-instant': {'confidence': 0.3961, 'value': -1.587},
#           'dur-minutes': {'confidence': 0.3961, 'value': -1.1114},
#           'dur-months': {'confidence': 0.3961, 'value': 0.8155},
#           'dur-seconds': {'confidence': 0.3961, 'value': -1.3735},
#           'dur-weeks': {'confidence': 0.3961, 'value': 0.8403},
#           'dur-years': {'confidence': 0.3961, 'value': -0.9796}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-637-semantics-pred-9
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.9999983906745911,
#                                  'value': 1.295220971107483},
#                      'natural_parts': {'confidence': 0.9999984502792358,
#                                        'value': -1.0770506858825684},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -1.5688},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.3034},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -1.4309},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -1.5377},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.4379},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.6498},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -1.544},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.4845},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -1.3085},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': 1.4595},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -1.4618},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.2559},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -1.527},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.2557},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -1.3876},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -1.4948},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -1.3936},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': 1.4018},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -1.4919},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.4348},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -1.2624},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.534},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -1.4182},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.206},
#                      'telic': {'confidence': 0.9999983906745911,
#                                'value': 1.295236349105835}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': -2.3865},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': -2.3865},
#                 'pred-particular': {'confidence': 1.0, 'value': 0.5391}},
#  'time': {'dur-centuries': {'confidence': 0.2808, 'value': -1.1952},
#           'dur-days': {'confidence': 0.2808, 'value': 0.808},
#           'dur-decades': {'confidence': 0.2808, 'value': -1.4092},
#           'dur-forever': {'confidence': 0.2808, 'value': -1.2707},
#           'dur-hours': {'confidence': 0.2808, 'value': -1.1687},
#           'dur-instant': {'confidence': 0.2808, 'value': -1.3048},
#           'dur-minutes': {'confidence': 0.2808, 'value': 0.7124},
#           'dur-months': {'confidence': 0.2808, 'value': 0.8374},
#           'dur-seconds': {'confidence': 0.2808, 'value': -1.5046},
#           'dur-weeks': {'confidence': 0.2808, 'value': -1.4204},
#           'dur-years': {'confidence': 0.2808, 'value': 0.7033}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-637-semantics-pred-14
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.999997615814209,
#                                  'value': 1.2715122699737549},
#                      'natural_parts': {'confidence': 0.999998927116394,
#                                        'value': -1.096170425415039},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -2.1133},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.2792},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -1.3808},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -0.4841},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.4709},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.307},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -0.442},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.4654},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': 1.3378},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': -1.4337},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -1.4766},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': -1.5621},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -2.1133},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.2792},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -1.3808},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -0.4841},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.4709},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.307},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -0.442},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.4654},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': 1.3378},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.4337},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -1.4766},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': -1.5621},
#                      'telic': {'confidence': 0.999998927116394,
#                                'value': -1.0961610078811646}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.0616}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 0.5391},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': -2.3865},
#                 'pred-particular': {'confidence': 1.0, 'value': 0.5391}},
#  'time': {'dur-centuries': {'confidence': 0.3985, 'value': -0.9767},
#           'dur-days': {'confidence': 0.3985, 'value': -1.14},
#           'dur-decades': {'confidence': 0.3985, 'value': -1.2714},
#           'dur-forever': {'confidence': 0.3985, 'value': -1.1871},
#           'dur-hours': {'confidence': 0.3985, 'value': -1.0792},
#           'dur-instant': {'confidence': 0.3985, 'value': -1.4671},
#           'dur-minutes': {'confidence': 0.3985, 'value': -0.9526},
#           'dur-months': {'confidence': 0.3985, 'value': 0.9762},
#           'dur-seconds': {'confidence': 0.3985, 'value': -1.3045},
#           'dur-weeks': {'confidence': 0.3985, 'value': 0.8199},
#           'dur-years': {'confidence': 0.3985, 'value': 0.9712}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-637-semantics-pred-22
#
# {'domain': 'semantics',
#  'event_structure': {'avg_part_duration_lbound-centuries': {'confidence': 1,
#                                                             'value': -0.5352},
#                      'avg_part_duration_lbound-days': {'confidence': 1,
#                                                        'value': -1.3404},
#                      'avg_part_duration_lbound-decades': {'confidence': 1,
#                                                           'value': -0.535},
#                      'avg_part_duration_lbound-forever': {'confidence': 1,
#                                                           'value': -1.6573},
#                      'avg_part_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                         'value': -1.274},
#                      'avg_part_duration_lbound-hours': {'confidence': 1,
#                                                         'value': -1.3165},
#                      'avg_part_duration_lbound-instant': {'confidence': 1,
#                                                           'value': -2.8191},
#                      'avg_part_duration_lbound-minutes': {'confidence': 1,
#                                                           'value': -1.4455},
#                      'avg_part_duration_lbound-months': {'confidence': 1,
#                                                          'value': -1.1115},
#                      'avg_part_duration_lbound-seconds': {'confidence': 1,
#                                                           'value': 1.8104},
#                      'avg_part_duration_lbound-weeks': {'confidence': 1,
#                                                         'value': -0.9693},
#                      'avg_part_duration_lbound-years': {'confidence': 1,
#                                                         'value': -1.1075},
#                      'avg_part_duration_ubound-centuries': {'confidence': 1,
#                                                             'value': -0.4326},
#                      'avg_part_duration_ubound-days': {'confidence': 1,
#                                                        'value': -1.2186},
#                      'avg_part_duration_ubound-decades': {'confidence': 1,
#                                                           'value': -0.4405},
#                      'avg_part_duration_ubound-forever': {'confidence': 1,
#                                                           'value': -1.533},
#                      'avg_part_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                         'value': -1.1446},
#                      'avg_part_duration_ubound-hours': {'confidence': 1,
#                                                         'value': -1.2213},
#                      'avg_part_duration_ubound-instant': {'confidence': 1,
#                                                           'value': -2.7671},
#                      'avg_part_duration_ubound-minutes': {'confidence': 1,
#                                                           'value': 1.5612},
#                      'avg_part_duration_ubound-months': {'confidence': 1,
#                                                          'value': -0.9843},
#                      'avg_part_duration_ubound-seconds': {'confidence': 1,
#                                                           'value': -1.0897},
#                      'avg_part_duration_ubound-weeks': {'confidence': 1,
#                                                         'value': -0.8391},
#                      'avg_part_duration_ubound-years': {'confidence': 1,
#                                                         'value': -0.986},
#                      'natural_parts': {'confidence': 0.999997615814209,
#                                        'value': 1.2702032327651978},
#                      'part_similarity': {'confidence': 0.999997615814209,
#                                          'value': 1.2701977491378784},
#                      'telic': {'confidence': 0.9999976754188538,
#                                'value': 1.2701661586761475}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.0834}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': 0.5391},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': 0.5391},
#                 'pred-particular': {'confidence': 1.0, 'value': 0.5392}},
#  'time': {'dur-centuries': {'confidence': 0.4439, 'value': -0.9898},
#           'dur-days': {'confidence': 0.4439, 'value': -1.1128},
#           'dur-decades': {'confidence': 0.4439, 'value': -1.1923},
#           'dur-forever': {'confidence': 0.4439, 'value': -1.1106},
#           'dur-hours': {'confidence': 0.4439, 'value': -1.1052},
#           'dur-instant': {'confidence': 0.4439, 'value': -0.8507},
#           'dur-minutes': {'confidence': 0.4439, 'value': -1.0563},
#           'dur-months': {'confidence': 0.4439, 'value': 0.9271},
#           'dur-seconds': {'confidence': 0.4439, 'value': -1.3028},
#           'dur-weeks': {'confidence': 0.4439, 'value': 0.7123},
#           'dur-years': {'confidence': 0.4439, 'value': 0.9681}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-637-semantics-pred-24
#
# {'domain': 'semantics',
#  'event_structure': {'dynamic': {'confidence': 0.9999983310699463,
#                                  'value': 1.1761362552642822},
#                      'natural_parts': {'confidence': 0.9999984502792358,
#                                        'value': -1.1939433813095093},
#                      'situation_duration_lbound-centuries': {'confidence': 1,
#                                                              'value': -2.8523},
#                      'situation_duration_lbound-days': {'confidence': 1,
#                                                         'value': -1.7645},
#                      'situation_duration_lbound-decades': {'confidence': 1,
#                                                            'value': -1.1014},
#                      'situation_duration_lbound-forever': {'confidence': 1,
#                                                            'value': -2.3534},
#                      'situation_duration_lbound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.9594},
#                      'situation_duration_lbound-hours': {'confidence': 1,
#                                                          'value': -1.2959},
#                      'situation_duration_lbound-instant': {'confidence': 1,
#                                                            'value': -1.7708},
#                      'situation_duration_lbound-minutes': {'confidence': 1,
#                                                            'value': -1.5501},
#                      'situation_duration_lbound-months': {'confidence': 1,
#                                                           'value': -1.176},
#                      'situation_duration_lbound-seconds': {'confidence': 1,
#                                                            'value': -1.4945},
#                      'situation_duration_lbound-weeks': {'confidence': 1,
#                                                          'value': -1.1825},
#                      'situation_duration_lbound-years': {'confidence': 1,
#                                                          'value': 1.6413},
#                      'situation_duration_ubound-centuries': {'confidence': 1,
#                                                              'value': -2.8523},
#                      'situation_duration_ubound-days': {'confidence': 1,
#                                                         'value': -1.7644},
#                      'situation_duration_ubound-decades': {'confidence': 1,
#                                                            'value': -1.1014},
#                      'situation_duration_ubound-forever': {'confidence': 1,
#                                                            'value': -2.3534},
#                      'situation_duration_ubound-fractions_of_a_second': {'confidence': 1,
#                                                                          'value': -0.9594},
#                      'situation_duration_ubound-hours': {'confidence': 1,
#                                                          'value': -1.2959},
#                      'situation_duration_ubound-instant': {'confidence': 1,
#                                                            'value': -1.7708},
#                      'situation_duration_ubound-minutes': {'confidence': 1,
#                                                            'value': -1.5501},
#                      'situation_duration_ubound-months': {'confidence': 1,
#                                                           'value': -1.176},
#                      'situation_duration_ubound-seconds': {'confidence': 1,
#                                                            'value': -1.4945},
#                      'situation_duration_ubound-weeks': {'confidence': 1,
#                                                          'value': -1.1825},
#                      'situation_duration_ubound-years': {'confidence': 1,
#                                                          'value': 1.6413},
#                      'telic': {'confidence': 0.9999985098838806,
#                                'value': -1.1939499378204346}},
#  'factuality': {'factual': {'confidence': 1.0, 'value': 1.0834}},
#  'frompredpatt': True,
#  'genericity': {'pred-dynamic': {'confidence': 1.0, 'value': -0.5366},
#                 'pred-hypothetical': {'confidence': 1.0, 'value': 2.2529},
#                 'pred-particular': {'confidence': 1.0, 'value': 2.2529}},
#  'time': {'dur-centuries': {'confidence': 0.3762, 'value': -0.9435},
#           'dur-days': {'confidence': 0.3762, 'value': 0.9353},
#           'dur-decades': {'confidence': 0.3762, 'value': -1.2182},
#           'dur-forever': {'confidence': 0.3762, 'value': -1.2919},
#           'dur-hours': {'confidence': 0.3762, 'value': -1.0213},
#           'dur-instant': {'confidence': 0.3762, 'value': -1.6631},
#           'dur-minutes': {'confidence': 0.3762, 'value': -0.945},
#           'dur-months': {'confidence': 0.3762, 'value': 0.8095},
#           'dur-seconds': {'confidence': 0.3762, 'value': -1.2592},
#           'dur-weeks': {'confidence': 0.3762, 'value': 0.8025},
#           'dur-years': {'confidence': 0.3762, 'value': 1.0472}},
#  'type': 'predicate'}
#
# PREDICATE:   ewt-train-637-semantics-pred-root
#
# {'domain': 'semantics', 'frompredpatt': False, 'type': 'predicate'}

# %% [markdown]
# Big nested dictionaries! Will need to dig in further to see what these dictionaries contain and get specific node type subspaces.

# %%
print(uds["ewt-dev-539"].predicate_nodes['ewt-dev-539-semantics-pred-4'].keys())
print()
print(uds["ewt-dev-539"].predicate_nodes['ewt-dev-539-semantics-pred-4'].items())
# Out:
# dict_keys(['domain', 'frompredpatt', 'type', 'event_structure', 'genericity', 'factuality', 'time'])
#
# dict_items([('domain', 'semantics'), ('frompredpatt', True), ('type', 'predicate'), ('event_structure', {'dynamic': {'value': 0.07712224125862122, 'confidence': 0.5674227476119995}, 'natural_parts': {'value': -1.0767347812652588, 'confidence': 0.9999988675117493}, 'telic': {'value': -1.076088786125183, 'confidence': 0.9999988675117493}, 'situation_duration_lbound-centuries': {'value': -0.685, 'confidence': 1}, 'situation_duration_ubound-centuries': {'value': -0.685, 'confidence': 1}, 'situation_duration_lbound-days': {'value': -1.4659, 'confidence': 1}, 'situation_duration_ubound-days': {'value': -1.4659, 'confidence': 1}, 'situation_duration_lbound-decades': {'value': -1.0697, 'confidence': 1}, 'situation_duration_ubound-decades': {'value': -1.0697, 'confidence': 1}, 'situation_duration_lbound-forever': {'value': 1.6609, 'confidence': 1}, 'situation_duration_ubound-forever': {'value': 1.6609, 'confidence': 1}, 'situation_duration_lbound-fractions_of_a_second': {'value': -1.0107, 'confidence': 1}, 'situation_duration_ubound-fractions_of_a_second': {'value': -1.0107, 'confidence': 1}, 'situation_duration_lbound-hours': {'value': -1.9219, 'confidence': 1}, 'situation_duration_ubound-hours': {'value': -1.9219, 'confidence': 1}, 'situation_duration_lbound-instant': {'value': -0.1895, 'confidence': 1}, 'situation_duration_ubound-instant': {'value': -0.1895, 'confidence': 1}, 'situation_duration_lbound-minutes': {'value': -1.9988, 'confidence': 1}, 'situation_duration_ubound-minutes': {'value': -1.9988, 'confidence': 1}, 'situation_duration_lbound-months': {'value': -1.0494, 'confidence': 1}, 'situation_duration_ubound-months': {'value': -1.0494, 'confidence': 1}, 'situation_duration_lbound-seconds': {'value': 0.1533, 'confidence': 1}, 'situation_duration_ubound-seconds': {'value': 0.1533, 'confidence': 1}, 'situation_duration_lbound-weeks': {'value': -0.8787, 'confidence': 1}, 'situation_duration_ubound-weeks': {'value': -0.8787, 'confidence': 1}, 'situation_duration_lbound-years': {'value': -1.5155, 'confidence': 1}, 'situation_duration_ubound-years': {'value': -1.5155, 'confidence': 1}}), ('genericity', {'pred-dynamic': {'confidence': 1.0, 'value': 1.1015}, 'pred-hypothetical': {'confidence': 0.6153, 'value': -0.1813}, 'pred-particular': {'confidence': 1.0, 'value': 1.1015}}), ('factuality', {'factual': {'confidence': 0.968, 'value': -0.336}}), ('time', {'dur-weeks': {'confidence': 0.4814, 'value': 0.4335}, 'dur-decades': {'confidence': 0.4814, 'value': -1.5445}, 'dur-days': {'confidence': 0.4814, 'value': 0.673}, 'dur-hours': {'confidence': 0.4814, 'value': 0.7887}, 'dur-seconds': {'confidence': 0.4814, 'value': -1.1141}, 'dur-forever': {'confidence': 0.4814, 'value': -1.4368}, 'dur-centuries': {'confidence': 0.4814, 'value': -1.3204}, 'dur-instant': {'confidence': 0.4814, 'value': -1.5695}, 'dur-years': {'confidence': 0.4814, 'value': -1.2676}, 'dur-minutes': {'confidence': 0.4814, 'value': 1.1613}, 'dur-months': {'confidence': 0.4814, 'value': -1.4104}})])

# %%
print_udep('ewt-train-133')
# Out:
# ewt-train-133
# Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
# ewt-train-133-syntax-1	Musharraf	Musharraf	NNP	PROPN	ewt-train-133-syntax-4:nsubj
# ewt-train-133-syntax-2	has	have	VBZ	AUX	ewt-train-133-syntax-4:aux
# ewt-train-133-syntax-3	been	be	VBN	AUX	ewt-train-133-syntax-4:aux
# ewt-train-133-syntax-4	trying	try	VBG	VERB	ewt-train-133-root-0:root
# ewt-train-133-syntax-5	to	to	TO	PART	ewt-train-133-syntax-6:mark
# ewt-train-133-syntax-6	purge	purge	VB	VERB	ewt-train-133-syntax-4:xcomp
# ewt-train-133-syntax-7	his	he	PRP$	PRON	ewt-train-133-syntax-9:nmod:poss
# ewt-train-133-syntax-8	officer	officer	NN	NOUN	ewt-train-133-syntax-9:compound
# ewt-train-133-syntax-9	corps	corps	NN	NOUN	ewt-train-133-syntax-6:dobj
# ewt-train-133-syntax-10	of	of	IN	ADP	ewt-train-133-syntax-13:case
# ewt-train-133-syntax-11	the	the	DT	DET	ewt-train-133-syntax-13:det
# ewt-train-133-syntax-12	substantial	substantial	JJ	ADJ	ewt-train-133-syntax-13:amod
# ewt-train-133-syntax-13	number	number	NN	NOUN	ewt-train-133-syntax-6:nmod
# ewt-train-133-syntax-14	of	of	IN	ADP	ewt-train-133-syntax-18:case
# ewt-train-133-syntax-15	al	al	NNP	PROPN	ewt-train-133-syntax-17:compound
# ewt-train-133-syntax-16	-	-	HYPH	PUNCT	ewt-train-133-syntax-17:punct
# ewt-train-133-syntax-17	Qaeda	Qaeda	NNP	PROPN	ewt-train-133-syntax-18:compound
# ewt-train-133-syntax-18	sympathizers	sympathizer	NNS	NOUN	ewt-train-133-syntax-13:nmod
# ewt-train-133-syntax-19	.	.	.	PUNCT	ewt-train-133-syntax-4:punct

# %% [markdown]
# So the "try" here is the root, and the "purge" verb is dependent on it as an xcomp (open clausal complement).
#
# *see: https://universaldependencies.org/u/dep/xcomp.html*
#
# From looking at the CoNNL-U format dataset (manually), I know that the predicates dependent on "try" in "try" constructions of interest are dependent in the xcomp relation. Let's test again (ID from list of "try" sentences):

# %%
print_udep('ewt-train-11637')
# Out:
# ewt-train-11637
# I eventually decided to just pay the balance even though the doctor has already been paid , but now the collection agency is trying to say another reversal of $ 160.00 has come through .
# ewt-train-11637-syntax-1	I	I	PRP	PRON	ewt-train-11637-syntax-3:nsubj
# ewt-train-11637-syntax-2	eventually	eventually	RB	ADV	ewt-train-11637-syntax-3:advmod
# ewt-train-11637-syntax-3	decided	decide	VBD	VERB	ewt-train-11637-root-0:root
# ewt-train-11637-syntax-4	to	to	TO	PART	ewt-train-11637-syntax-6:mark
# ewt-train-11637-syntax-5	just	just	RB	ADV	ewt-train-11637-syntax-6:advmod
# ewt-train-11637-syntax-6	pay	pay	VB	VERB	ewt-train-11637-syntax-3:xcomp
# ewt-train-11637-syntax-7	the	the	DT	DET	ewt-train-11637-syntax-8:det
# ewt-train-11637-syntax-8	balance	balance	NN	NOUN	ewt-train-11637-syntax-6:dobj
# ewt-train-11637-syntax-9	even	even	RB	ADV	ewt-train-11637-syntax-16:advmod
# ewt-train-11637-syntax-10	though	though	IN	SCONJ	ewt-train-11637-syntax-16:mark
# ewt-train-11637-syntax-11	the	the	DT	DET	ewt-train-11637-syntax-12:det
# ewt-train-11637-syntax-12	doctor	doctor	NN	NOUN	ewt-train-11637-syntax-16:nsubjpass
# ewt-train-11637-syntax-13	has	have	VBZ	AUX	ewt-train-11637-syntax-16:aux
# ewt-train-11637-syntax-14	already	already	RB	ADV	ewt-train-11637-syntax-16:advmod
# ewt-train-11637-syntax-15	been	be	VBN	AUX	ewt-train-11637-syntax-16:auxpass
# ewt-train-11637-syntax-16	paid	pay	VBN	VERB	ewt-train-11637-syntax-6:advcl
# ewt-train-11637-syntax-17	,	,	,	PUNCT	ewt-train-11637-syntax-3:punct
# ewt-train-11637-syntax-18	but	but	CC	CONJ	ewt-train-11637-syntax-3:cc
# ewt-train-11637-syntax-19	now	now	RB	ADV	ewt-train-11637-syntax-24:advmod
# ewt-train-11637-syntax-20	the	the	DT	DET	ewt-train-11637-syntax-22:det
# ewt-train-11637-syntax-21	collection	collection	NN	NOUN	ewt-train-11637-syntax-22:compound
# ewt-train-11637-syntax-22	agency	agency	NN	NOUN	ewt-train-11637-syntax-24:nsubj
# ewt-train-11637-syntax-23	is	be	VBZ	AUX	ewt-train-11637-syntax-24:aux
# ewt-train-11637-syntax-24	trying	try	VBG	VERB	ewt-train-11637-syntax-3:conj
# ewt-train-11637-syntax-25	to	to	TO	PART	ewt-train-11637-syntax-26:mark
# ewt-train-11637-syntax-26	say	say	VB	VERB	ewt-train-11637-syntax-24:xcomp
# ewt-train-11637-syntax-27	another	another	DT	DET	ewt-train-11637-syntax-28:det
# ewt-train-11637-syntax-28	reversal	reversal	NN	NOUN	ewt-train-11637-syntax-33:nsubj
# ewt-train-11637-syntax-29	of	of	IN	ADP	ewt-train-11637-syntax-30:case
# ewt-train-11637-syntax-30	$	$	$	SYM	ewt-train-11637-syntax-28:nmod
# ewt-train-11637-syntax-31	160.00	160.00	CD	NUM	ewt-train-11637-syntax-30:nummod
# ewt-train-11637-syntax-32	has	have	VBZ	AUX	ewt-train-11637-syntax-33:aux
# ewt-train-11637-syntax-33	come	come	VBN	VERB	ewt-train-11637-syntax-26:ccomp
# ewt-train-11637-syntax-34	through	through	RB	ADV	ewt-train-11637-syntax-33:advmod
# ewt-train-11637-syntax-35	.	.	.	PUNCT	ewt-train-11637-syntax-3:punct

# %% [markdown]
# "try" here is dependent on "decide", and yep, "say" is dependent on "try" in xcomp relation.

# %% [markdown]
# ### 4-1. Trying out helper functions (from Na-Rae - thank you!)

# %%
def find_xcomp(*args):
    """takes two arguments as a list: tree ID, and node1 ID which corresponds to the try verb's ID
    returns node ID of the token that's dependent on the try verb with xcomp relation"""
    tree, node1 = args[0], args[1]
    edges = uds[tree].syntax_edges()
    for ((n1,n2),v) in edges.items():
        if n1==node1 and v['deprel']=='xcomp':
            return(n2)

# %%
find_xcomp('ewt-train-133', 'ewt-train-133-syntax-4')
# Out:
# 'ewt-train-133-syntax-6'

# %%
find_xcomp('ewt-train-133', 'ewt-train-133-syntax-2')
# no xcomp dependent node; returns null

# %%
def get_node_info(s,nodeid):
    "takes sentence_id and node_id, returns form, lemma, xpos, upos"
    ndict= uds[s].syntax_nodes[nodeid]
    return (ndict['form'], ndict['lemma'], ndict['xpos'], ndict['upos'])

# %%
get_node_info('ewt-train-133', 'ewt-train-133-syntax-18')
# Out:
# ('sympathizers', 'sympathizer', 'NNS', 'NOUN')

# %%
def get_form(s,nodeid):
    "takes sentence_id and node_id, returns form"
    ndict= uds[s].syntax_nodes[nodeid]
    return (ndict['form'])

# %%
def get_lemma(s,nodeid):
    "takes sentence_id and node_id, returns lemma"
    ndict= uds[s].syntax_nodes[nodeid]
    return (ndict['lemma'])

# %%
def get_head_node(s,nodeid):
    "takes sentence_id and node_id, returns its head node and dep relation"
    edge_dict = {e2:(e1,v['deprel']) for ((e1,e2),v) in uds[s].syntax_edges().items()}
    return (edge_dict[nodeid])

# %%
get_head_node('ewt-train-133', 'ewt-train-133-syntax-6')
# "purge" is dependent on node 4 'try' in 'xcomp' relation
# Out:
# ('ewt-train-133-syntax-4', 'xcomp')

# %% [markdown]
# ### 4-2. Types of relations

# %% [markdown]
# Sentences containing "try" constructions contain predicates dependent on "try" with differing relations.

# %%
# 'try' sentences where xcomp node IS NOT found

for (s,trid) in try_sents_id[:30]:
    #print(s,trid)
    if not find_xcomp(s,trid):   
        print(s)
        print(uds[s].sentence)
        print()
# Out:
# ewt-train-668
# Moreover there are now major covert attempts under way to try and bring back to Kabul leading Taliban commanders , who have been living quietly in Pakistan and have taken no part in the Taliban insurgency .
#
# ewt-train-701
# In a highly significant move Afghan Pashtun tribes along the Pakistan border warned the Taliban in Quetta and Chaman that if they try and disrupt the elections , they would be resisted .
#
# ewt-train-1288
# It is trying to play ice hockey by sending a ballerina ice - skater into the ring or to knock out a heavyweight boxer by a chess player .
#
# ewt-train-3431
# Let s try before Fri , as I am planning to take that day off
#
# ewt-train-4384
# Try this .

# %%
# 'try' sentences where xcomp node IS found

for (s,trid) in try_sents_id[:10]:  # out of first 10
    #print(s,trid)
    if find_xcomp(s,trid):   # cases where xcomp node IS found
        print(s)
        print(trid, get_node_info(s,trid))
        xcompid = find_xcomp(s,trid)  # node ID for the xcomp verb
        print(xcompid, get_node_info(s,xcompid)) 
        print(uds[s].sentence)
        print()
# Out:
# ewt-train-133
# ewt-train-133-syntax-4 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-133-syntax-6 ('purge', 'purge', 'VB', 'VERB')
# Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
#
# ewt-train-637
# ewt-train-637-syntax-22 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-637-syntax-24 ('strengthen', 'strengthen', 'VB', 'VERB')
# The neighbours are still interfering , but there are signs that rather than undermining Afghanistan 's stability they may now be trying to strengthen it .
#
# ewt-train-688
# ewt-train-688-syntax-8 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-688-syntax-10 ('undermine', 'undermine', 'VB', 'VERB')
# However powerful hardliners in Tehran may be trying to undermine that strategy and a new issue is likely to deepen the rift with the moderates .
#
# ewt-train-796
# ewt-train-796-syntax-3 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-796-syntax-5 ('buddy', 'buddy', 'VB', 'VERB')
# He was trying to buddy with Archibald and impress him .
#
# ewt-train-881
# ewt-train-881-syntax-13 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-881-syntax-15 ('get', 'get', 'VB', 'VERB')
# I read of a case not long ago when some people were trying to get a polygamous judge taken off the bench for not obeying state law .
#
# ewt-train-917
# ewt-train-917-syntax-26 ('tried', 'try', 'VBD', 'VERB')
# ewt-train-917-syntax-28 ('absorb', 'absorb', 'VB', 'VERB')
# Afshari , who was posted in Germany and was responsible for receiving Mujahedeen children during the gulf war , said that when the German government tried to absorb Mujahedeen children into their education system , the Mujahedeen refused .
#
# ewt-train-1195
# ewt-train-1195-syntax-20 ('try', 'try', 'VBP', 'VERB')
# ewt-train-1195-syntax-22 ('explain', 'explain', 'VB', 'VERB')
# If part of the public supports it , others tolerate it , many are afraid of it and some try to explain it away by poverty or by a miserable childhood , organized crime will thrive and so will terrorism .
#
# ewt-train-1267
# ewt-train-1267-syntax-8 ('trying', 'try', 'VBG', 'VERB')
# ewt-train-1267-syntax-10 ('kill', 'kill', 'VB', 'VERB')
# Can a policeman open fire on someone trying to kill him ?

# %% [markdown]
# ## 5. Specific info for sentences with "try" constructions

# %% [markdown]
# I want to be able to see the ID, text, and predicate information about these sentences.

# %%
# initializing lists

sentence_id     = []
sentence        = []
try_id          = []
try_form        = []
try_lemma       = []
after_try_id    = []
after_try_form  = []
after_try_lemma = []

# populating lists

for (s,trid) in try_sents_id:    
    if find_xcomp(s,trid):   # cases where xcomp node IS found
        xcompid = find_xcomp(s,trid) 
        tr_form = get_form(s,trid).lower()   # lowercased because form could have both cases
        tr_lemma = get_lemma(s,trid)
        after_tr_form = get_form(s,xcompid)
        after_tr_lemma = get_lemma(s,xcompid)
        sent = uds[s].sentence   
        sentence_id.append(s)
        sentence.append(sent)
        try_id.append(trid)
        try_form.append(tr_form)
        try_lemma.append(tr_lemma)
        after_try_id.append(xcompid)
        after_try_form.append(after_tr_form)
        after_try_lemma.append(after_tr_lemma)

# %%
# checking

print(try_id[:2])
print(try_lemma[:2])
print(after_try_form[:2])
# Out:
# ['ewt-train-133-syntax-4', 'ewt-train-637-syntax-22']
# ['try', 'try']
# ['purge', 'strengthen']

# %% [markdown]
# Seems good!

# %% [markdown]
# ### 5-1. Create DataFrame with sentence and word info

# %%
# create dataframe from above lists

df = pd.DataFrame(list(zip(sentence_id, sentence, try_id, try_form, try_lemma, after_try_id, after_try_form, after_try_lemma)),
                 columns = ['sentence_id', 'sentence_text', 'try_id', 'try_form', 'try_lemma', 'after_try_id', 'after_try_form', 'after_try_lemma'])

# %%
# show dataframe

df
# Out:
#        sentence_id                                      sentence_text  \
# 0    ewt-train-133  Musharraf has been trying to purge his officer...
# 1    ewt-train-637  The neighbours are still interfering , but the...
# 2    ewt-train-688  However powerful hardliners in Tehran may be t...
# 3    ewt-train-796  He was trying to buddy with Archibald and impr...
# 4    ewt-train-881  I read of a case not long ago when some people...
# ..             ...                                                ...
# 152  ewt-test-1361  o and the cheaper the better ( we are trying t...
# 153  ewt-test-1368  just pray for her ad=nd try to hlep your dog a...
# 154  ewt-test-1474  I have a friend out in Chicago this week , and...
# 155  ewt-test-1817  When I tried to return it they refused , so I ...
# 156  ewt-test-1981  I used to take my cars there all the time , bu...
#
#                       try_id try_form try_lemma             after_try_id  \
# 0     ewt-train-133-syntax-4   trying       try   ewt-train-133-syntax-6
# 1    ewt-train-637-syntax-22   trying       try  ewt-train-637-syntax-24
# 2     ewt-train-688-syntax-8   trying       try  ewt-train-688-syntax-10
# 3     ewt-train-796-syntax-3   trying       try   ewt-train-796-syntax-5
# 4    ewt-train-881-syntax-13   trying       try  ewt-train-881-syntax-15
# ..                       ...      ...       ...                      ...
# 152  ewt-test-1361-syntax-10   trying       try  ewt-test-1361-syntax-12
# 153   ewt-test-1368-syntax-6      try       try   ewt-test-1368-syntax-8
# 154  ewt-test-1474-syntax-14   trying       try  ewt-test-1474-syntax-16
# 155   ewt-test-1817-syntax-3    tried       try   ewt-test-1817-syntax-5
# 156  ewt-test-1981-syntax-28      try       try  ewt-test-1981-syntax-31
#
#     after_try_form after_try_lemma
# 0            purge           purge
# 1       strengthen      strengthen
# 2        undermine       undermine
# 3            buddy           buddy
# 4              get             get
# ..             ...             ...
# 152           save            save
# 153           hlep            hlep
# 154       remember        remember
# 155         return          return
# 156            add             add
#
# [157 rows x 8 columns]

# %%
# info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentence_id      157 non-null    object
#  1   sentence_text    157 non-null    object
#  2   try_id           157 non-null    object
#  3   try_form         157 non-null    object
#  4   try_lemma        157 non-null    object
#  5   after_try_id     157 non-null    object
#  6   after_try_form   157 non-null    object
#  7   after_try_lemma  157 non-null    object
# dtypes: object(8)
# memory usage: 9.9+ KB

# %% [markdown]
# Looks like there are 157 different "try" constructions.

# %%
# describe

df.describe()
# Out:
#            sentence_id                                      sentence_text  \
# count              157                                                157
# unique             154                                                152
# top     ewt-train-7580  with your leg flopping , just try putting all ...
# freq                 2                                                  2
#
#                           try_id try_form try_lemma             after_try_id  \
# count                        157      157       157                      157
# unique                       157        4         1                      157
# top     ewt-train-7580-syntax-13   trying       try  ewt-train-8817-syntax-3
# freq                           1       64       157                        1
#
#        after_try_form after_try_lemma
# count             157             157
# unique            106             102
# top               get             get
# freq               14              14

# %% [markdown]
# What is going on with the number of unique instances?

# %%
df.loc[df['sentence_id'] == 'ewt-train-9073']
# Out:
#        sentence_id                                      sentence_text  \
# 82  ewt-train-9073  with your leg flopping , just try putting all ...
# 83  ewt-train-9073  with your leg flopping , just try putting all ...
#
#                       try_id try_form try_lemma              after_try_id  \
# 82   ewt-train-9073-syntax-7      try       try   ewt-train-9073-syntax-8
# 83  ewt-train-9073-syntax-47      try       try  ewt-train-9073-syntax-48
#
#    after_try_form after_try_lemma
# 82        putting             put
# 83       standing           stand

# %% [markdown]
# Looks like sentence ewt-train-9073 appears twice.

# %%
df.loc[82].sentence_text
# Out:
# "with your leg flopping , just try putting all your weight in your heel and hang on with only your legs , holding my leg back helps me with flopping the more it 's forward the more it flops :/ work your calf muscles , maybe try standing on the edge of your steps ( on the ball of your foot ) and balance to strengthen those muscles"

# %% [markdown]
# So, sentence ewt-train-9073 appears twice because there are two different "try" constructions in it!

# %%
# different "try" forms (remember, these were lowercased)

df.try_form.value_counts()
# Out:
# trying    64
# try       59
# tried     33
# tries      1
# Name: try_form, dtype: int64

# %%
# top 15 words after "try"

df.after_try_form.value_counts().head(15)
# Out:
# get          14
# make          5
# find          5
# bite          4
# keep          4
# do            4
# help          3
# develop       3
# eat           3
# googling      2
# kill          2
# translate     2
# explain       2
# charge        2
# build         2
# Name: after_try_form, dtype: int64

# %% [markdown]
# Some form of "try" + "get" is the most common "try" predicate construction at 14 instances in the data.

# %% [markdown]
# ## 6. Closer look at node type subspaces (of interest)
#
# I am interested in analyzing the semantics of both the "try" predicate and the predicate dependent on the "try" predicate in the xcomp relation, specifically the extent to which the predicates involved in the "try" construction occurred.
#
# After reading through the [Universal Decompositional Semantic Types page](https://decomp.readthedocs.io/en/latest/data/semantic-types.html#) and seeing the different types of information available for the predicates and arguments, I figured that factuality, telicity, and the hypothetical attribute of genericity may be interesting to look at more in depth for my purposes.

# %% [markdown]
# ### 6-1. Factuality
#
# from http://decomp.io/projects/factuality/
#
# "A central function of natural language is to convey information about the properties of events. Perhaps the most fundamental of these properties is factuality: whether an event happened or not."
#
# "In this line of work, we develop a factuality annotation that incorporates a notion of confidence. This allows us to handle a wide variety of cases where the factuality of an event is unclear."
#
# - node type subspace `factuality`

# %% [markdown]
# ### 6-2. Event structure
#
# from http://decomp.io/projects/event-structure/
#
# "In this work, we aim to capture the structure of complex events, augmenting existing UDS with a new dataset for event-structural properties that capture information about such things as the subparts of an event, how they are arranged in time, and how events relate to each other and their participants."
#
# "We use this new dataset along with others in UDS to induce an empircal event structure ontology from a generative model based on sentence- and document-level UDS graphs. This ontology is jointly learned with three other ontologies for semantic roles, entities, and event-event relations. In each case, we find that our categories align well with others proposed in the linguistics and computational semantics literature."
#
# - node type subspace `event_structure`
#
# of interest:
# - `telic`: dealing with a clear endpoint to an action

# %% [markdown]
# ### 6-3. Genericity
#
# from http://decomp.io/projects/genericity/
#
# "An important line of study in formal semantics, philosophy, and AI investigates how language is used to represent knowledge of kinds, regularities and patterns."
#
# "In this line of work, we propose a novel framework for capturing linguistic expressions of generalization. We suggest that linguistic expressions of generalization should be captured in a continuous multi-label system, rather than a multi-class system. We do this by decomposing categories such as EPISODIC, HABITUAL, and GENERIC into simple referential properties of predicates and their arguments."
#
# - node type subspace `genericity`
#
# of interest:
# - `pred-hypothetical`

# %% [markdown]
# ### 6-4. Values for subspaces

# %%
# formatted list of sentences, predicates, and 
# information of interest for each predicate
# only first 2 as sample

for (s,trid) in try_sents_id[:2]:   
    if find_xcomp(s,trid):
        print('========================================================================', '\n')
        print('SENTENCE:', '\n', uds[s].name, '\n', uds[s].sentence, '\n')
        print('PREDICATES:')
        for pred in uds[s].predicate_nodes.keys():
            print(pred)
            if uds[s].predicate_nodes[pred]['frompredpatt']:
                print(uds[s].head(pred, ['form', 'lemma']))
        print('\n')
        for pred in uds[s].predicate_nodes:
            print('PREDICATE:', pred)
            #pprint(uds[s].predicate_nodes[pred])
            print()
            for (n, v) in uds[s].predicate_nodes[pred].items():
                if n == 'event_structure':
                    #print(n + ': ', v)
                    #print()
                    for (x, y) in v.items():
                        if x == 'telic':
                            print(x, '\n', 'Value:', y['value'], '\n', 'Confidence:', y['confidence'])
                            print()
                if n == 'genericity':
                    for (x, y) in v.items():
                        if x == 'pred-hypothetical':
                            print(x, '\n', 'Value:', y['value'], '\n', 'Confidence:', y['confidence'])
                            print()
                if n == 'factuality': 
                    for (x, y) in v.items():
                        if x == 'factual':
                            print(x, '\n', 'Value:', y['value'], '\n', 'Confidence:', y['confidence'])
                            print()
                if n == 'time':
                    for (x, y) in v.items():
                        print(x, '\n', 'Value:', y['value'], '\n', 'Confidence:', y['confidence'], '\n')          
            print()
# Out:
# ========================================================================
#
# SENTENCE:
#  ewt-train-133
#  Musharraf has been trying to purge his officer corps of the substantial number of al - Qaeda sympathizers .
#
# PREDICATES:
# ewt-train-133-semantics-pred-4
# (4, ['trying', 'try'])
# ewt-train-133-semantics-pred-6
# (6, ['purge', 'purge'])
# ewt-train-133-semantics-pred-root
#
#
# PREDICATE: ewt-train-133-semantics-pred-4
#
# telic
#  Value: 1.2817955017089844
#  Confidence: 0.9999978542327881
#
# pred-hypothetical
#  Value: -0.7177
#  Confidence: 1.0
#
# factual
#  Value: 1.2194
#  Confidence: 1.0
#
# dur-weeks
#  Value: -1.3455
#  Confidence: 1.0
#
# dur-decades
#  Value: -1.1133
#  Confidence: 1.0
#
# dur-days
#  Value: -1.2002
#  Confidence: 1.0
#
# dur-hours
#  Value: -1.1744
#  Confidence: 1.0
#
# dur-seconds
#  Value: -0.9131
#  Confidence: 1.0
#
# dur-forever
#  Value: -0.3098
#  Confidence: 1.0
#
# dur-centuries
#  Value: -0.8337
#  Confidence: 1.0
#
# dur-instant
#  Value: -0.4054
#  Confidence: 1.0
#
# dur-years
#  Value: -1.0219
#  Confidence: 1.0
#
# dur-minutes
#  Value: -1.0265
#  Confidence: 1.0
#
# dur-months
#  Value: 1.0446
#  Confidence: 1.0
#
#
# PREDICATE: ewt-train-133-semantics-pred-6
#
# telic
#  Value: -1.1354095935821533
#  Confidence: 0.9999986886978149
#
# pred-hypothetical
#  Value: 0.4279
#  Confidence: 1.0
#
# factual
#  Value: 0.2707
#  Confidence: 0.8706
#
# dur-weeks
#  Value: 0.6508
#  Confidence: 0.5836
#
# dur-decades
#  Value: -1.0465
#  Confidence: 0.5836
#
# dur-days
#  Value: -1.2104
#  Confidence: 0.5836
#
# dur-hours
#  Value: -1.1908
#  Confidence: 0.5836
#
# dur-seconds
#  Value: -0.9104
#  Confidence: 0.5836
#
# dur-forever
#  Value: -0.4961
#  Confidence: 0.5836
#
# dur-centuries
#  Value: -0.98
#  Confidence: 0.5836
#
# dur-instant
#  Value: -0.5634
#  Confidence: 0.5836
#
# dur-years
#  Value: -1.0337
#  Confidence: 0.5836
#
# dur-minutes
#  Value: -1.0486
#  Confidence: 0.5836
#
# dur-months
#  Value: 0.8781
#  Confidence: 0.5836
#
#
# PREDICATE: ewt-train-133-semantics-pred-root
#
#
# ========================================================================
#
# SENTENCE:
#  ewt-train-637
#  The neighbours are still interfering , but there are signs that rather than undermining Afghanistan 's stability they may now be trying to strengthen it .
#
# PREDICATES:
# ewt-train-637-semantics-pred-5
# (5, ['interfering', 'interfere'])
# ewt-train-637-semantics-pred-9
# (9, ['are', 'be'])
# ewt-train-637-semantics-pred-14
# (14, ['undermining', 'undermine'])
# ewt-train-637-semantics-pred-22
# (22, ['trying', 'try'])
# ewt-train-637-semantics-pred-24
# (24, ['strengthen', 'strengthen'])
# ewt-train-637-semantics-pred-root
#
#
# PREDICATE: ewt-train-637-semantics-pred-5
#
# telic
#  Value: -1.0744456052780151
#  Confidence: 0.9999987483024597
#
# pred-hypothetical
#  Value: -1.3616
#  Confidence: 1.0
#
# factual
#  Value: 1.0498
#  Confidence: 1.0
#
# dur-weeks
#  Value: 0.8403
#  Confidence: 0.3961
#
# dur-decades
#  Value: 0.8798
#  Confidence: 0.3961
#
# dur-days
#  Value: 1.0418
#  Confidence: 0.3961
#
# dur-hours
#  Value: -0.9873
#  Confidence: 0.3961
#
# dur-seconds
#  Value: -1.3735
#  Confidence: 0.3961
#
# dur-forever
#  Value: -1.1847
#  Confidence: 0.3961
#
# dur-centuries
#  Value: -0.9553
#  Confidence: 0.3961
#
# dur-instant
#  Value: -1.587
#  Confidence: 0.3961
#
# dur-years
#  Value: -0.9796
#  Confidence: 0.3961
#
# dur-minutes
#  Value: -1.1114
#  Confidence: 0.3961
#
# dur-months
#  Value: 0.8155
#  Confidence: 0.3961
#
#
# PREDICATE: ewt-train-637-semantics-pred-9
#
# telic
#  Value: 1.295236349105835
#  Confidence: 0.9999983906745911
#
# pred-hypothetical
#  Value: -2.3865
#  Confidence: 1.0
#
# dur-weeks
#  Value: -1.4204
#  Confidence: 0.2808
#
# dur-decades
#  Value: -1.4092
#  Confidence: 0.2808
#
# dur-days
#  Value: 0.808
#  Confidence: 0.2808
#
# dur-hours
#  Value: -1.1687
#  Confidence: 0.2808
#
# dur-seconds
#  Value: -1.5046
#  Confidence: 0.2808
#
# dur-forever
#  Value: -1.2707
#  Confidence: 0.2808
#
# dur-centuries
#  Value: -1.1952
#  Confidence: 0.2808
#
# dur-instant
#  Value: -1.3048
#  Confidence: 0.2808
#
# dur-years
#  Value: 0.7033
#  Confidence: 0.2808
#
# dur-minutes
#  Value: 0.7124
#  Confidence: 0.2808
#
# dur-months
#  Value: 0.8374
#  Confidence: 0.2808
#
#
# PREDICATE: ewt-train-637-semantics-pred-14
#
# telic
#  Value: -1.0961610078811646
#  Confidence: 0.999998927116394
#
# pred-hypothetical
#  Value: -2.3865
#  Confidence: 1.0
#
# factual
#  Value: 1.0616
#  Confidence: 1.0
#
# dur-weeks
#  Value: 0.8199
#  Confidence: 0.3985
#
# dur-decades
#  Value: -1.2714
#  Confidence: 0.3985
#
# dur-days
#  Value: -1.14
#  Confidence: 0.3985
#
# dur-hours
#  Value: -1.0792
#  Confidence: 0.3985
#
# dur-seconds
#  Value: -1.3045
#  Confidence: 0.3985
#
# dur-forever
#  Value: -1.1871
#  Confidence: 0.3985
#
# dur-centuries
#  Value: -0.9767
#  Confidence: 0.3985
#
# dur-instant
#  Value: -1.4671
#  Confidence: 0.3985
#
# dur-years
#  Value: 0.9712
#  Confidence: 0.3985
#
# dur-minutes
#  Value: -0.9526
#  Confidence: 0.3985
#
# dur-months
#  Value: 0.9762
#  Confidence: 0.3985
#
#
# PREDICATE: ewt-train-637-semantics-pred-22
#
# telic
#  Value: 1.2701661586761475
#  Confidence: 0.9999976754188538
#
# pred-hypothetical
#  Value: 0.5391
#  Confidence: 1.0
#
# factual
#  Value: 1.0834
#  Confidence: 1.0
#
# dur-weeks
#  Value: 0.7123
#  Confidence: 0.4439
#
# dur-decades
#  Value: -1.1923
#  Confidence: 0.4439
#
# dur-days
#  Value: -1.1128
#  Confidence: 0.4439
#
# dur-hours
#  Value: -1.1052
#  Confidence: 0.4439
#
# dur-seconds
#  Value: -1.3028
#  Confidence: 0.4439
#
# dur-forever
#  Value: -1.1106
#  Confidence: 0.4439
#
# dur-centuries
#  Value: -0.9898
#  Confidence: 0.4439
#
# dur-instant
#  Value: -0.8507
#  Confidence: 0.4439
#
# dur-years
#  Value: 0.9681
#  Confidence: 0.4439
#
# dur-minutes
#  Value: -1.0563
#  Confidence: 0.4439
#
# dur-months
#  Value: 0.9271
#  Confidence: 0.4439
#
#
# PREDICATE: ewt-train-637-semantics-pred-24
#
# telic
#  Value: -1.1939499378204346
#  Confidence: 0.9999985098838806
#
# pred-hypothetical
#  Value: 2.2529
#  Confidence: 1.0
#
# factual
#  Value: 1.0834
#  Confidence: 1.0
#
# dur-weeks
#  Value: 0.8025
#  Confidence: 0.3762
#
# dur-decades
#  Value: -1.2182
#  Confidence: 0.3762
#
# dur-days
#  Value: 0.9353
#  Confidence: 0.3762
#
# dur-hours
#  Value: -1.0213
#  Confidence: 0.3762
#
# dur-seconds
#  Value: -1.2592
#  Confidence: 0.3762
#
# dur-forever
#  Value: -1.2919
#  Confidence: 0.3762
#
# dur-centuries
#  Value: -0.9435
#  Confidence: 0.3762
#
# dur-instant
#  Value: -1.6631
#  Confidence: 0.3762
#
# dur-years
#  Value: 1.0472
#  Confidence: 0.3762
#
# dur-minutes
#  Value: -0.945
#  Confidence: 0.3762
#
# dur-months
#  Value: 0.8095
#  Confidence: 0.3762
#
#
# PREDICATE: ewt-train-637-semantics-pred-root

# %% [markdown]
# According to the [published literature on the UDS dataset](https://aclanthology.org/2020.lrec-1.699.pdf), the values for each attribute come from crowd-sourced annotations. These annotations are binary responses (YES/NO) in response to simple questions about the predicates, and then along with them, there is a 1-5 confidence rating (how confident the annotator feels about their YES or NO answer) that gets normalized. The confidence is the researcher confidence score dealing with how accurate the researcher believes the annotators' responses to be (there will be a lower confidence score if the annotator responses are more variable). Confidence is on [0,1].

# %% [markdown]
# ### 6-5. Lists for tracking values

# %%
telic_value         = []
hypothetical_value  = []
factuality_value    = []

for (s,trid) in try_sents_id:   
    if find_xcomp(s,trid):
        for pred in uds[s].predicate_nodes:
            for (n, v) in uds[s].predicate_nodes[pred].items():
                if n == 'event_structure':
                    for (x, y) in v.items():
                        if x == 'telic':
                            telic_value.append(y['value'])
                if n == 'genericity':
                    for (x, y) in v.items():
                        if x == 'pred-hypothetical':
                            hypothetical_value.append(y['value'])
                if n == 'factuality': 
                    for (x, y) in v.items():
                        if x == 'factual':
                            factuality_value.append(y['value'])
                #if n == 'time':
                    #for (x, y) in v.items():
                        #print(x, '\n', 'Value:', y['value'], '\n', 'Confidence:', y['confidence'], '\n')          
            #print()

# %%
print(telic_value[:5])
print(hypothetical_value[:5])
print(factuality_value[:5])
# Out:
# [1.2817955017089844, -1.1354095935821533, -1.0744456052780151, 1.295236349105835, -1.0961610078811646]
# [-0.7177, 0.4279, -1.3616, -2.3865, -2.3865]
# [1.2194, 0.2707, 1.0498, 1.0616, 1.0834]
