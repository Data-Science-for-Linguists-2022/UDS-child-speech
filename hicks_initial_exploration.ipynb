# %% [markdown]
# # Initial exploration of CHILDES Narrative English Hicks Corpus
#
# ## Caroline Gish | cng18@pitt.edu | for 2022-02-24
#
# ---
#
# **Source:** https://childes.talkbank.org/access/Eng-NA/Hicks.html
#
# Initial exploration will involve

# %%
from chamd import ChatReader

# %%
from chamd import ChatReader
reader = ChatReader()
chat = reader.read_file('data/Hicks/1st/event/evt004.cha') # or read_string

for item in chat.metadata:
    print(item)
for line in chat.lines:
    for item in line.metadata:
        print(item)
    print(line.text)
# Out:
# charencoding
# childage
# childmonths
# comment
# date
# pid
# session
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# so this is again Deborah and Ari .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and we're gonna be sportscasters .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and say what's happening in the movie .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and I'm gonna start .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# the little boy is getting some money out .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# he's walking into the bakery shop .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he's telling his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# to wait .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# he's walking in .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and now some other boys are coming around .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and looking at things .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# to eat .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# would you like to be the sportscaster now .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and say what's happening ?
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# so then they catch the balloon around the bakery .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then the boy comes out .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and looks for his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he walks out .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he looks up .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he still doesn't see his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he sees .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# the boys running after it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# so he runs after them .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he looks around for the boys and his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he runs back .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he sees .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# them going over climbing up a wall .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then they go up some stairs .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and trying to keep the balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and they tie another string onto it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he's up on a hill .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# trying to look trying to see .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# where his balloon is .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and then the boy shoots a needle into the balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and it starts shrinking a little bit .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he sees his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he says
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# come here come here .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# but the balloon doesn't come here .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# so he runs for it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and the boy's gonna shoot a the boy and one of the boys has a slingshot .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he's gonna shoot a needle into it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and there's a door in the gate .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he's trying to push it open .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he's looking through the keyhole .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and then he reaches to his balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# but there's another string attached to it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# so then he's getting pulled up the wall .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and the boys are trying to pull it .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he gets away .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then all the boys climb over the wall .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and the boy starts running .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and all the boys run after him .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then he runs past a dog .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and down the stairs .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and through the alleys .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and keeps on running and running and running and running .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and all the boys are running after him .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and then he runs past a lady .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then all the boys try to run past the lady .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# but they couldn't .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and he runs through more alleys and more alleys .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and and then the boys see so when the boys see him with the red balloon .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# then they chase after him .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and then there's and then he runs past a rock .
# origutt
# parsefile
# speaker
# uttendlineno
# uttid
# uttstartlineno
# name
# SES
# age
# corpus
# custom
# education
# group
# language
# months
# role
# sex
# and I think we're gonna stop here .
